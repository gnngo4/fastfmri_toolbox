# %%
fla_dir = "/data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla"

# %%
from fla_utils import create_temp_file, search
import os
import subprocess
import gzip
import shutil
import nibabel as nib
import numpy as np
from pathlib import Path

def cifti_separate(dscalar):
    data = {}
    data['volume'] = create_temp_file('.nii')
    data['cortex_left'] = create_temp_file('.func.gii')
    data['cortex_right'] = create_temp_file('.func.gii')
    # Separate dsclar
    cmd = f"wb_command -cifti-separate {dscalar} COLUMN -volume-all {data['volume']} -metric CORTEX_LEFT {data['cortex_left']} -metric CORTEX_RIGHT {data['cortex_right']}"
    os.system(cmd)
    for i in data.values():
        assert Path(i).exists()
    # Uncompress format
    for func in [data['cortex_left'], data['cortex_right']]:
        cmd = f"wb_command -gifti-convert BASE64_BINARY {func} {func}"
        os.system(cmd)
    
    return data

def get_surface_vertex_areas(
    surf_left="/data/dump/surfaces/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii", 
    surf_right="/data/dump/surfaces/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii"
):
    for s in [surf_left, surf_right]:
        assert Path(s).exists()
    data = {}
    for hemi, surf_path in zip(
        ['cortex_left','cortex_right'],
        [surf_left,surf_right]
    ):
        data[hemi] = create_temp_file('.func.gii')
        cmd = f"wb_command -surface-vertex-areas {surf_path} {data[hemi]}"
        os.system(cmd)
        assert Path(data[hemi]).exists()
        
    return data

def merge_niftis(niftis):
    merged_nifti = create_temp_file('.nii')
    cmd = f"fslmerge -t {merged_nifti} {' '.join(niftis)}"
    os.system(cmd)
    assert Path(merged_nifti).exists()

    return merged_nifti

def merge_metrics(func_giis):
    merged_func_gii = create_temp_file('.func.gii')
    cmd = f"wb_command -metric-merge {merged_func_gii} -metric {' -metric '.join(func_giis)}"
    os.system(cmd)
    assert Path(merged_func_gii).exists()

    return merged_func_gii

# %% [markdown]
# NIFTIs - PALM

# %%
# Inputs
oscprep_base_dir = "/data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless"
experiment_id = '00_experiment-min'
data_type = 'CIFTI'
sub_id = '002'
ses_id = '02'
frequencies = [.125,.2]
out_dir = f"/data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_{data_type}/sub-{sub_id}_ses-{ses_id}"
surfaces = {
    'cortex_left': "/data/dump/surfaces/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii",
    'cortex_right': "/data/dump/surfaces/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii",
}

test_flag = False

temp_files = [] # Track tmp files
for ix, _frequency in enumerate(frequencies):
    
    if ix > 0 and test_flag:
        break

    # Grab all ciftis for one-sample t-test
    ciftis, n_runs = {}, {}
    for task_id in ['entrain', 'control']:
        _ciftis = !ls {fla_dir}/{experiment_id}/{data_type}/sub-{sub_id}/ses-{ses_id}/task-{task_id}*/run-??/GLM/frequency*{_frequency}_z_score.dscalar.nii
        _ciftis.sort()
        ciftis[task_id] = _ciftis
        n_runs[task_id] = len(ciftis[task_id])

    # Create design matrix (.csv)
    design_matrix = np.zeros((sum(n_runs.values()), 2))
    idx1, idx2 = 0, 0
    for ix, _n_runs in enumerate(n_runs.values()):
        if ix > 0:
            idx1 += _n_runs
        idx2 += _n_runs
        design_matrix[idx1:idx2, ix] = 1        
    dm_csv = create_temp_file('.csv')
    with open(dm_csv, 'w') as f:
        for ix, i in enumerate(range(design_matrix.shape[0])):
            f.write(','.join([str(j) for j in design_matrix[i,:]]))
            if ix == design_matrix.shape[0] - 1:
                continue
            f.write('\n')
    temp_files.append(dm_csv) # Track tmp files

    # Create contrast (.csv)
    contrast_matrix = np.zeros((3,2))
    # Two sample t-test [entrain>control]
    contrast_matrix[0,0] = 1
    contrast_matrix[0,1] = -1
    contrast_matrix[1,0] = 1 # one sample t-test [entrain]
    contrast_matrix[2,1] = 1 # one sample t-test [control]
    contrast_csv = create_temp_file('.csv')
    with open(contrast_csv, 'w') as f:
        for ix,i in enumerate(range(contrast_matrix.shape[0])):
            f.write(','.join([str(j) for j in contrast_matrix[i,:]]))
            if ix == contrast_matrix.shape[0] - 1:
                continue
            f.write('\n')
    temp_files.append(contrast_csv) # Track tmp files

    # Concatenate all niftis across task conditions into a single list
    # Note: they must be ordered according to the design matrix
    listify_ciftis = ciftis['entrain'] + ciftis['control']

    # Separate ciftis
    listify_sep_ciftis = {}
    for ix, dscalar in enumerate(listify_ciftis):
        separated_dscalar = cifti_separate(dscalar)
        for k, v in separated_dscalar.items():
            if ix == 0:
                listify_sep_ciftis[k] = [v]
            else:
                listify_sep_ciftis[k].append(v)
            temp_files.append(v)

    # Merge separated ciftis
    merged_sep_cifti = {}
    merged_sep_cifti['volume'] = merge_niftis(listify_sep_ciftis['volume'])
    merged_sep_cifti['cortex_left'] = merge_metrics(listify_sep_ciftis['cortex_left'])
    merged_sep_cifti['cortex_right'] = merge_metrics(listify_sep_ciftis['cortex_right'])
    for k, v in merged_sep_cifti.items():
        temp_files.append(v)

    # Get surface and corresponding surface-vertex-area files
    surface_areas = get_surface_vertex_areas(surfaces['cortex_left'], surfaces['cortex_right'])
    for k, v in surface_areas.items():
        temp_files.append(v)

    # Verbose
    print(f'RUNNING: Frequency - {_frequency}')
    for _cifti in listify_ciftis:
        print(f"   - {_cifti}")

    # Run palm thrice, (1) volume, (2) CORTEX_LEFT, (3) CORTEX_RIGHT
    # Volume
    # !/opt/PALM/run_palm.sh /opt/matlab \
        -i {merged_sep_cifti['volume']} \
        -d {dm_csv} \
        -t {contrast_csv} \
        -o {out_dir}/frequency-{str(_frequency).replace('.','')}_subcortical \
        -n 500 \
        -T -logp
    # Cortex Left
    # !/opt/PALM/run_palm.sh /opt/matlab \
        -i {merged_sep_cifti['cortex_left']} \
        -s {surfaces['cortex_left']} {surface_areas['cortex_left']} \
        -d {dm_csv} \
        -t {contrast_csv} \
        -o {out_dir}/frequency-{str(_frequency).replace('.','')}_CortexLeft \
        -n 500 \
        -T -tfce2D -logp
    # Cortex Right
    # !/opt/PALM/run_palm.sh /opt/matlab \
        -i {merged_sep_cifti['cortex_right']} \
        -s {surfaces['cortex_right']} {surface_areas['cortex_right']} \
        -d {dm_csv} \
        -t {contrast_csv} \
        -o {out_dir}/frequency-{str(_frequency).replace('.','')}_CortexRight \
        -n 500 \
        -T -tfce2D -logp
    
# Remove all contrast files
for f in temp_files:
    os.remove(f)
# Out:
# RUNNING: Frequency - 0.125
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-entrainQ1/run-01/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-entrainQ1/run-02/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-entrainQ1/run-03/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-entrainQ1/run-04/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-entrainQ1/run-05/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-entrainQ1/run-06/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-entrainQ1/run-07/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-entrainQ1/run-08/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-controlQ1/run-01/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-controlQ1/run-02/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-controlQ1/run-03/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-controlQ1/run-04/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-controlQ1/run-05/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-controlQ1/run-06/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-controlQ1/run-07/GLM/frequency-0.125_z_score.dscalar.nii
#    - /data/fastfmri_toolbox_test_data/3T/bids/derivatives/oscprep_grayords_fmapless_fla/00_experiment-min/CIFTI/sub-002/ses-02/task-controlQ1/run-08/GLM/frequency-0.125_z_score.dscalar.nii
# ------------------------------------------
# Setting up environment variables
# ---
# LD_LIBRARY_PATH is .:/opt/matlab/runtime/glnxa64:/opt/matlab/bin/glnxa64:/opt/matlab/sys/os/glnxa64:/opt/matlab/sys/opengl/lib/glnxa64
# .......................................................................
# =======================================================================
#              ___         ___                         ___
#             /  /\       /  /\                       /__/\
#            /  /::\     /  /::\                     |  |::\
#           /  /:/\:\   /  /:/\:\    ___     ___     |  |:|:\
#          /  /:/~/:/  /  /:/~/::\  /__/\   /  /\  __|__|:|\:\
#         /__/:/ /:/  /__/:/ /:/\:\ \  \:\ /  /:/ /__/::::| \:\
#         \  \:\/:/   \  \:\/:/__\/  \  \:\  /:/  \  \:\~~\__\/
#          \  \::/     \  \::/        \  \:\/:/    \  \:\
#           \  \:\      \  \:\         \  \::/      \  \:\
#            \  \:\      \  \:\         \__\/        \  \:\
#             \__\/       \__\/                       \__\/
#
# =======================================================================
#                  Permutation Analysis of Linear Models
# =======================================================================
# Running PALM (github using MATLAB 9.10.0.2198249 (R2021a) Update 8 with the following options:
# -i /tmp/tmpnic15t57.nii
# -d /tmp/tmpoccx27e2.csv
# -t /tmp/tmp880feive.csv
# -o /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-0125_subcortical
# -n 500
# -T
# -logp
# Reading input 1/1: /tmp/tmpnic15t57.nii
# Warning: Name is nonexistent or not a directory: /opt/fsl-6.0.5.1/etc/matlab
# > In path (line 109)
# In addpath (line 86)
# In palm_checkprogs (line 45)
# In palm_miscread (line 152)
# In palm_ready (line 47)
# In palm_takeargs (line 1649)
# In palm_core (line 33)
# In palm (line 81)
# Found FSL in /opt/fsl-6.0.5.1
# Warning: Name is nonexistent or not a directory: /opt/freesurfer/matlab
# > In path (line 109)
# In addpath (line 86)
# In palm_checkprogs (line 54)
# In palm_miscread (line 152)
# In palm_ready (line 47)
# In palm_takeargs (line 1649)
# In palm_core (line 33)
# In palm (line 81)
# Found FreeSurfer in /opt/freesurfer
# Found SPM in /root/.mcrCache9.10/palm_d0/home/nobuaki/spm12
# Found HCP Workbench executable in /opt/workbench/bin_linux64/wb_command
# Warning: Name is nonexistent or not a directory: /root/.mcrCache9.10/palm_d0/palm/fileio
# > In path (line 109)
# In addpath (line 86)
# In palm_checkprogs (line 83)
# In palm_miscread (line 152)
# In palm_ready (line 47)
# In palm_takeargs (line 1649)
# In palm_core (line 33)
# In palm (line 81)
# Warning: Name is nonexistent or not a directory: /root/.mcrCache9.10/palm_d0/palm/fileio/extras
# > In path (line 109)
# In addpath (line 86)
# In palm_checkprogs (line 84)
# In palm_miscread (line 152)
# In palm_ready (line 47)
# In palm_takeargs (line 1649)
# In palm_core (line 33)
# In palm (line 81)
# Warning: Name is nonexistent or not a directory: /root/.mcrCache9.10/palm_d0/palm/fileio/freesurfer
# > In path (line 109)
# In addpath (line 86)
# In palm_checkprogs (line 85)
# In palm_miscread (line 152)
# In palm_ready (line 47)
# In palm_takeargs (line 1649)
# In palm_core (line 33)
# In palm (line 81)
# Warning: Name is nonexistent or not a directory: /root/.mcrCache9.10/palm_d0/palm/colourmaps
# > In path (line 109)
# In addpath (line 86)
# In palm_checkprogs (line 88)
# In palm_miscread (line 152)
# In palm_ready (line 47)
# In palm_takeargs (line 1649)
# In palm_core (line 33)
# In palm (line 81)
# Error using read_hdr (line 39)
# Error reading header file "/tmp/tmpnic15t57.nii".
#
# Error in nifti (line 26)
#
# Error in palm_miscread (line 173)
#
# Error in palm_ready (line 47)
#
# Error in palm_takeargs (line 1649)
#
# Error in palm_core (line 33)
#
# Error in palm (line 81)
#
#
# ------------------------------------------
# Setting up environment variables
# ---
# LD_LIBRARY_PATH is .:/opt/matlab/runtime/glnxa64:/opt/matlab/bin/glnxa64:/opt/matlab/sys/os/glnxa64:/opt/matlab/sys/opengl/lib/glnxa64
# .......................................................................
# =======================================================================
#              ___         ___                         ___
#             /  /\       /  /\                       /__/\
#            /  /::\     /  /::\                     |  |::\
#           /  /:/\:\   /  /:/\:\    ___     ___     |  |:|:\
#          /  /:/~/:/  /  /:/~/::\  /__/\   /  /\  __|__|:|\:\
#         /__/:/ /:/  /__/:/ /:/\:\ \  \:\ /  /:/ /__/::::| \:\
#         \  \:\/:/   \  \:\/:/__\/  \  \:\  /:/  \  \:\~~\__\/
#          \  \::/     \  \::/        \  \:\/:/    \  \:\
#           \  \:\      \  \:\         \  \::/      \  \:\
#            \  \:\      \  \:\         \__\/        \  \:\
#             \__\/       \__\/                       \__\/
#
# =======================================================================
#                  Permutation Analysis of Linear Models
# =======================================================================
# Running PALM (github using MATLAB 9.10.0.2198249 (R2021a) Update 8 with the following options:
# -i /tmp/tmpb97ch11z.func.gii
# -s /data/dump/surfaces/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /tmp/tmpxtqt8bic.func.gii
# -d /tmp/tmpoccx27e2.csv
# -t /tmp/tmp880feive.csv
# -o /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-0125_CortexLeft
# -n 500
# -T
# -tfce2D
# -logp
# Loading surface 1/1: /data/dump/surfaces/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii
# Reading input 1/1: /tmp/tmpb97ch11z.func.gii
# Reading design matrix and contrasts.
# Elapsed time parsing inputs: ~ 2.66617 seconds.
# Number of possible permutations is 12870.
# Generating 500 shufflings (permutations only).
# Building null distribution.
# 0.0667%	 [Design 1/1, Contrast 1/3, Shuffling 1/500, Modality 1/1]
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency
# 27.9%	 [Design 1/1, Contrast 1/3, Shuffling 419/500, Modality 1/1]
# 28%	 [Design 1/1, Contrast 1/3, Shuffling 420/500, Modality 1/1]
# 28.1%	 [Design 1/1, Contrast 1/3, Shuffling 421/500, Modality 1/1]
# 28.1%	 [Design 1/1, Contrast 1/3, Shuffling 422/500, Modality 1/1]
# 28.2%	 [Design 1/1, Contrast 1/3, Shuffling 423/500, Modality 1/1]
# 28.3%	 [Design 1/1, Contrast 1/3, Shuffling 424/500, Modality 1/1]
# 28.3%	 [Design 1/1, Contrast 1/3, Shuffling 425/500, Modality 1/1]
# 28.4%	 [Design 1/1, Contrast 1/3, Shuffling 426/500, Modality 1/1]
# 28.5%	 [Design 1/1, Contrast 1/3, Shuffling 427/500, Modality 1/1]
# 28.5%	 [Design 1/1, Contrast 1/3, Shuffling 428/500, Modality 1/1]
# 28.6%	 [Design 1/1, Contrast 1/3, Shuffling 429/500, Modality 1/1]
# 28.7%	 [Design 1/1, Contrast 1/3, Shuffling 430/500, Modality 1/1]
# 28.7%	 [Design 1/1, Contrast 1/3, Shuffling 431/500, Modality 1/1]
# 28.8%	 [Design 1/1, Contrast 1/3, Shuffling 432/500, Modality 1/1]
# 28.9%	 [Design 1/1, Contrast 1/3, Shuffling 433/500, Modality 1/1]
# 28.9%	 [Design 1/1, Contrast 1/3, Shuffling 434/500, Modality 1/1]
# 29%	 [Design 1/1, Contrast 1/3, Shuffling 435/500, Modality 1/1]
# 29.1%	 [Design 1/1, Contrast 1/3, Shuffling 436/500, Modality 1/1]
# 29.1%	 [Design 1/1, Contrast 1/3, Shuffling 437/500, Modality 1/1]
# 29.2%	 [Design 1/1, Contrast 1/3, Shuffling 438/500, Modality 1/1]
# 29.3%	 [Design 1/1, Contrast 1/3, Shuffling 439/500, Modality 1/1]
# 29.3%	 [Design 1/1, Contrast 1/3, Shuffling 440/500, Modality 1/1]
# 29.4%	 [Design 1/1, Contrast 1/3, Shuffling 441/500, Modality 1/1]
# 29.5%	 [Design 1/1, Contrast 1/3, Shuffling 442/500, Modality 1/1]
# 29.5%	 [Design 1/1, Contrast 1/3, Shuffling 443/500, Modality 1/1]
# 29.6%	 [Design 1/1, Contrast 1/3, Shuffling 444/500, Modality 1/1]
# 29.7%	 [Design 1/1, Contrast 1/3, Shuffling 445/500, Modality 1/1]
# 29.7%	 [Design 1/1, Contrast 1/3, Shuffling 446/500, Modality 1/1]
# 29.8%	 [Design 1/1, Contrast 1/3, Shuffling 447/500, Modality 1/1]
# 29.9%	 [Design 1/1, Contrast 1/3, Shuffling 448/500, Modality 1/1]
# 29.9%	 [Design 1/1, Contrast 1/3, Shuffling 449/500, Modality 1/1]
# 30%	 [Design 1/1, Contrast 1/3, Shuffling 450/500, Modality 1/1]
# 30.1%	 [Design 1/1, Contrast 1/3, Shuffling 451/500, Modality 1/1]
# 30.1%	 [Design 1/1, Contrast 1/3, Shuffling 452/500, Modality 1/1]
# 30.2%	 [Design 1/1, Contrast 1/3, Shuffling 453/500, Modality 1/1]
# 32.6%	 [Design 1/1, Contrast 1/3, Shuffling 489/500, Modality 1/1]
# 32.7%	 [Design 1/1, Contrast 1/3, Shuffling 490/500, Modality 1/1]
# 32.7%	 [Design 1/1, Contrast 1/3, Shuffling 491/500, Modality 1/1]
# 32.8%	 [Design 1/1, Contrast 1/3, Shuffling 492/500, Modality 1/1]
# 32.9%	 [Design 1/1, Contrast 1/3, Shuffling 493/500, Modality 1/1]
# 32.9%	 [Design 1/1, Contrast 1/3, Shuffling 494/500, Modality 1/1]
# 33%	 [Design 1/1, Contrast 1/3, Shuffling 495/500, Modality 1/1]
# 33.1%	 [Design 1/1, Contrast 1/3, Shuffling 496/500, Modality 1/1]
# 33.1%	 [Design 1/1, Contrast 1/3, Shuffling 497/500, Modality 1/1]
# 33.2%	 [Design 1/1, Contrast 1/3, Shuffling 498/500, Modality 1/1]
# 33.3%	 [Design 1/1, Contrast 1/3, Shuffling 499/500, Modality 1/1]
# 33.3%	 [Design 1/1, Contrast 1/3, Shuffling 500/500, Modality 1/1]
# Number of possible permutations is 12870.
# Generating 500 shufflings (permutations only).
# Building null distribution.
# 33.4%	 [Design 1/1, Contrast 2/3, Shuffling 1/500, Modality 1/1]
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-0125_CortexLeft_dpv_tstat_c2
# 33.5%	 [Design 1/1, Contrast 2/3, Shuffling 2/500, Modality 1/1]
# 33.5%	 [Design 1/1, Contrast 2/3, Shuffling 3/500, Modality 1/1]
# 33.6%	 [Design 1/1, Contrast 2/3, Shuffling 4/500, Modality 1/1]
# 33.7%	 [Design 1/1, Contrast 2/3, Shuffling 5/500, Modality 1/1]
# 33.7%	 [Design 1/1, Contrast 2/3, Shuffling 6/500, Modality 1/1]
# 33.8%	 [Design 1/1, Contrast 2/3, Shuffling 7/500, Modality 1/1]
# 33.9%	 [Design 1/1, Contrast 2/3, Shuffling 8/500, Modality 1/1]
# 33.9%	 [Design 1/1, Contrast 2/3, Shuffling 9/500, Modality 1/1]
# 34%	 [Design 1/1, Contrast 2/3, Shuffling 10/500, Modality 1/1]
# 34.1%	 [Design 1/1, Contrast 2/3, Shuffling 11/500, Modality 1/1]
# 34.1%	 [Design 1/1, Contrast 2/3, Shuffling 12/500, Modality 1/1]
# 34.2%	 [Design 1/1, Contrast 2/3, Shuffling 13/500, Modality 1/1]
# 34.3%	 [Design 1/1, Contrast 2/3, Shuffling 14/500, Modality 1/1]
# 34.3%	 [Design 1/1, Contrast 2/3, Shuffling 15/500, Modality 1/1]
# 34.4%	 [Design 1/1, Contrast 2/3, Shuffling 16/500, Modality 1/1]
# 34.5%	 [Design 1/1, Contrast 2/3, Shuffling 17/500, Modality 1/1]
# 34.5%	 [Design 1/1, Contrast 2/3, Shuffling 18/500, Modality 1/1]
# 34.6%	 [Design 1/1, Contrast 2/3, Shuffling 19/500, Modality 1/1]
# 34.7%	 [Design 1/1, Contrast 2/3, Shuffling 20/500, Modality 1/1]
# 34.7%	 [Design 1/1, Contrast 2/3, Shuffling 21/500, Modality 1/1]
# 34.8%	 [Design 1/1, Contrast 2/3, Shuffling 22/500, Modality 1/1]
# 34.9%	 [Design 1/1, Contrast 2/3, Shuffling 23/500, Modality 1/1]
# 34.9%	 [Design 1/1, Contrast 2/3, Shuffling 24/500, Modality 1/1]
# 35%	 [Design 1/1, Contrast 2/3, Shuffling 25/500, Modality 1/1]
# 35.1%	 [Design 1/1, Contrast 2/3, Shuffling 26/500, Modality 1/1]
# 35.1%	 [Design 1/1, Contrast 2/3, Shuffling 27/500, Modality 1/1]
# 35.2%	 [Design 1/1, Contrast 2/3, Shuffling 28/500, Modality 1/1]
# 35.3%	 [Design 1/1, Contrast 2/3, Shuffling 29/500, Modality 1/1]
# 35.3%	 [Design 1/1, Contrast 2/3, Shuffling 30/500, Modality 1/1]
# 35.4%	 [Design 1/1, Contrast 2/3, Shuffling 31/500, Modality 1/1]
# 35.5%	 [Design 1/1, Contrast 2/3, Shuffling 32/500, Modality 1/1]
# 35.5%	 [Design 1/1, Contrast 2/3, Shuffling 33/500, Modality 1/1]
# 35.6%	 [Design 1/1, Contrast 2/3, Shuffling 34/500, Modality 1/1]
# 35.7%	 [Design 1/1, Contrast 2/3, Shuffling 35/500, Modality 1/1]
# 35.7%	 [Design 1/1, Contrast 2/3, Shuffling 36/500, Modality 1/1]
# 35.8%	 [Design 1/1, Contrast 2/3, Shuffling 37/500, Modality 1/1]
# 35.9%	 [Design 1/1, Contrast 2/3, Shuffling 38/500, Modality 1/1]
# 35.9%	 [Design 1/1, Contrast 2/3, Shuffling 39/500, Modality 1/1]
# 36%	 [Design 1/1, Contrast 2/3, Shuffling 40/500, Modality 1/1]
# 36.1%	 [Design 1/1, Contrast 2/3, Shuffling 41/500, Modality 1/1]
# 36.1%	 [Design 1/1, Contrast 2/3, Shuffling 42/500, Modality 1/1]
# 36.2%	 [Design 1/1, Contrast 2/3, Shuffling 43/500, Modality 1/1]
# 36.3%	 [Design 1/1, Contrast 2/3, Shuffling 44/500, Modality 1/1]
# 36.3%	 [Design 1/1, Contrast 2/3, Shuffling 45/500, Modality 1/1]
# 36.4%	 [Design 1/1, Contrast 2/3, Shuffling 46/500, Modality 1/1]
# 36.5%	 [Design 1/1, Contrast 2/3, Shuffling 47/500, Modality 1/1]
# 36.5%	 [Design 1/1, Contrast 2/3, Shuffling 48/500, Modality 1/1]
# 36.6%	 [Design 1/1, Contrast 2/3, Shuffling 49/500, Modality 1/1]
# 36.7%	 [Design 1/1, Contrast 2/3, Shuffling 50/500, Modality 1/1]
# 36.7%	 [Design 1/1, Contrast 2/3, Shuffling 51/500, Modality 1/1]
# 36.8%	 [Design 1/1, Contrast 2/3, Shuffling 52/500, Modality 1/1]
# 36.9%	 [Design 1/1, Contrast 2/3, Shuffling 53/500, Modality 1/1]
# 36.9%	 [Design 1/1, Contrast 2/3, Shuffling 54/500, Modality 1/1]
# 37%	 [Design 1/1, Contrast 2/3, Shuffling 55/500, Modality 1/1]
# 37.1%	 [Design 1/1, Contrast 2/3, Shuffling 56/500, Modality 1/1]
# 37.1%	 [Design 1/1, Contrast 2/3, Shuffling 57/500, Modality 1/1]
# 37.2%	 [Design 1/1, Contrast 2/3, Shuffling 58/500, Modality 1/1]
# 37.3%	 [Design 1/1, Contrast 2/3, Shuffling 59/500, Modality 1/1]
# 37.3%	 [Design 1/1, Contrast 2/3, Shuffling 60/500, Modality 1/1]
# 37.4%	 [Design 1/1, Contrast 2/3, Shuffling 61/500, Modality 1/1]
# 37.5%	 [Design 1/1, Contrast 2/3, Shuffling 62/500, Modality 1/1]
# 37.5%	 [Design 1/1, Contrast 2/3, Shuffling 63/500, Modality 1/1]
# 37.6%	 [Design 1/1, Contrast 2/3, Shuffling 64/500, Modality 1/1]
# 37.7%	 [Design 1/1, Contrast 2/3, Shuffling 65/500, Modality 1/1]
# 37.7%	 [Design 1/1, Contrast 2/3, Shuffling 66/500, Modality 1/1]
# 37.8%	 [Design 1/1, Contrast 2/3, Shuffling 67/500, Modality 1/1]
# 37.9%	 [Design 1/1, Contrast 2/3, Shuffling 68/500, Modality 1/1]
# 37.9%	 [Design 1/1, Contrast 2/3, Shuffling 69/500, Modality 1/1]
# 38%	 [Design 1/1, Contrast 2/3, Shuffling 70/500, Modality 1/1]
# 38.1%	 [Design 1/1, Contrast 2/3, Shuffling 71/500, Modality 1/1]
# 38.1%	 [Design 1/1, Contrast 2/3, Shuffling 72/500, Modality 1/1]
# 38.2%	 [Design 1/1, Contrast 2/3, Shuffling 73/500, Modality 1/1]
# 38.3%	 [Design 1/1, Contrast 2/3, Shuffling 74/500, Modality 1/1]
# 38.3%	 [Design 1/1, Contrast 2/3, Shuffling 75/500, Modality 1/1]
# 38.4%	 [Design 1/1, Contrast 2/3, Shuffling 76/500, Modality 1/1]
# 38.5%	 [Design 1/1, Contrast 2/3, Shuffling 77/500, Modality 1/1]
# 38.5%	 [Design 1/1, Contrast 2/3, Shuffling 78/500, Modality 1/1]
# 38.6%	 [Design 1/1, Contrast 2/3, Shuffling 79/500, Modality 1/1]
# 38.7%	 [Design 1/1, Contrast 2/3, Shuffling 80/500, Modality 1/1]
# 38.7%	 [Design 1/1, Contrast 2/3, Shuffling 81/500, Modality 1/1]
# 38.8%	 [Design 1/1, Contrast 2/3, Shuffling 82/500, Modality 1/1]
# 38.9%	 [Design 1/1, Contrast 2/3, Shuffling 83/500, Modality 1/1]
# 38.9%	 [Design 1/1, Contrast 2/3, Shuffling 84/500, Modality 1/1]
# 39%	 [Design 1/1, Contrast 2/3, Shuffling 85/500, Modality 1/1]
# ...
# 86.5%	 [Design 1/1, Contrast 3/3, Shuffling 298/500, Modality 1/1]
# 86.6%	 [Design 1/1, Contrast 3/3, Shuffling 299/500, Modality 1/1]
# 86.7%	 [Design 1/1, Contrast 3/3, Shuffling 300/500, Modality 1/1]
# 86.7%	 [Design 1/1, Contrast 3/3, Shuffling 301/500, Modality 1/1]
# 86.8%	 [Design 1/1, Contrast 3/3, Shuffling 302/500, Modality 1/1]
# 86.9%	 [Design 1/1, Contrast 3/3, Shuffling 303/500, Modality 1/1]
# 86.9%	 [Design 1/1, Contrast 3/3, Shuffling 304/500, Modality 1/1]
# 87%	 [Design 1/1, Contrast 3/3, Shuffling 305/500, Modality 1/1]
# 87.1%	 [Design 1/1, Contrast 3/3, Shuffling 306/500, Modality 1/1]
# 87.1%	 [Design 1/1, Contrast 3/3, Shuffling 307/500, Modality 1/1]
# 87.2%	 [Design 1/1, Contrast 3/3, Shuffling 308/500, Modality 1/1]
# 87.3%	 [Design 1/1, Contrast 3/3, Shuffling 309/500, Modality 1/1]
# 87.3%	 [Design 1/1, Contrast 3/3, Shuffling 310/500, Modality 1/1]
# 87.4%	 [Design 1/1, Contrast 3/3, Shuffling 311/500, Modality 1/1]
# 87.5%	 [Design 1/1, Contrast 3/3, Shuffling 312/500, Modality 1/1]
# 87.5%	 [Design 1/1, Contrast 3/3, Shuffling 313/500, Modality 1/1]
# 87.6%	 [Design 1/1, Contrast 3/3, Shuffling 314/500, Modality 1/1]
# 87.7%	 [Design 1/1, Contrast 3/3, Shuffling 315/500, Modality 1/1]
# 87.7%	 [Design 1/1, Contrast 3/3, Shuffling 316/500, Modality 1/1]
# 87.8%	 [Design 1/1, Contrast 3/3, Shuffling 317/500, Modality 1/1]
# 87.9%	 [Design 1/1, Contrast 3/3, Shuffling 318/500, Modality 1/1]
# 87.9%	 [Design 1/1, Contrast 3/3, Shuffling 319/500, Modality 1/1]
# 88%	 [Design 1/1, Contrast 3/3, Shuffling 320/500, Modality 1/1]
# 88.1%	 [Design 1/1, Contrast 3/3, Shuffling 321/500, Modality 1/1]
# 88.1%	 [Design 1/1, Contrast 3/3, Shuffling 322/500, Modality 1/1]
# 88.2%	 [Design 1/1, Contrast 3/3, Shuffling 323/500, Modality 1/1]
# 88.3%	 [Design 1/1, Contrast 3/3, Shuffling 324/500, Modality 1/1]
# 88.3%	 [Design 1/1, Contrast 3/3, Shuffling 325/500, Modality 1/1]
# 88.4%	 [Design 1/1, Contrast 3/3, Shuffling 326/500, Modality 1/1]
# 88.5%	 [Design 1/1, Contrast 3/3, Shuffling 327/500, Modality 1/1]
# 88.5%	 [Design 1/1, Contrast 3/3, Shuffling 328/500, Modality 1/1]
# 88.6%	 [Design 1/1, Contrast 3/3, Shuffling 329/500, Modality 1/1]
# 88.7%	 [Design 1/1, Contrast 3/3, Shuffling 330/500, Modality 1/1]
# 88.7%	 [Design 1/1, Contrast 3/3, Shuffling 331/500, Modality 1/1]
# 88.8%	 [Design 1/1, Contrast 3/3, Shuffling 332/500, Modality 1/1]
# 88.9%	 [Design 1/1, Contrast 3/3, Shuffling 333/500, Modality 1/1]
# 88.9%	 [Design 1/1, Contrast 3/3, Shuffling 334/500, Modality 1/1]
# 89%	 [Design 1/1, Contrast 3/3, Shuffling 335/500, Modality 1/1]
# 89.1%	 [Design 1/1, Contrast 3/3, Shuffling 336/500, Modality 1/1]
# 89.1%	 [Design 1/1, Contrast 3/3, Shuffling 337/500, Modality 1/1]
# 93.9%	 [Design 1/1, Contrast 3/3, Shuffling 408/500, Modality 1/1]
# 93.9%	 [Design 1/1, Contrast 3/3, Shuffling 409/500, Modality 1/1]
# 94%	 [Design 1/1, Contrast 3/3, Shuffling 410/500, Modality 1/1]
# 94.1%	 [Design 1/1, Contrast 3/3, Shuffling 411/500, Modality 1/1]
# 94.1%	 [Design 1/1, Contrast 3/3, Shuffling 412/500, Modality 1/1]
# 94.2%	 [Design 1/1, Contrast 3/3, Shuffling 413/500, Modality 1/1]
# 94.3%	 [Design 1/1, Contrast 3/3, Shuffling 414/500, Modality 1/1]
# 94.3%	 [Design 1/1, Contrast 3/3, Shuffling 415/500, Modality 1/1]
# 94.4%	 [Design 1/1, Contrast 3/3, Shuffling 416/500, Modality 1/1]
# 94.5%	 [Design 1/1, Contrast 3/3, Shuffling 417/500, Modality 1/1]
# 94.5%	 [Design 1/1, Contrast 3/3, Shuffling 418/500, Modality 1/1]
# 94.6%	 [Design 1/1, Contrast 3/3, Shuffling 419/500, Modality 1/1]
# 94.7%	 [Design 1/1, Contrast 3/3, Shuffling 420/500, Modality 1/1]
# 94.7%	 [Design 1/1, Contrast 3/3, Shuffling 421/500, Modality 1/1]
# 94.8%	 [Design 1/1, Contrast 3/3, Shuffling 422/500, Modality 1/1]
# 94.9%	 [Design 1/1, Contrast 3/3, Shuffling 423/500, Modality 1/1]
# 94.9%	 [Design 1/1, Contrast 3/3, Shuffling 424/500, Modality 1/1]
# 95%	 [Design 1/1, Contrast 3/3, Shuffling 425/500, Modality 1/1]
# 95.1%	 [Design 1/1, Contrast 3/3, Shuffling 426/500, Modality 1/1]
# 95.1%	 [Design 1/1, Contrast 3/3, Shuffling 427/500, Modality 1/1]
# 95.2%	 [Design 1/1, Contrast 3/3, Shuffling 428/500, Modality 1/1]
# 95.3%	 [Design 1/1, Contrast 3/3, Shuffling 429/500, Modality 1/1]
# 95.3%	 [Design 1/1, Contrast 3/3, Shuffling 430/500, Modality 1/1]
# 95.4%	 [Design 1/1, Contrast 3/3, Shuffling 431/500, Modality 1/1]
# 95.5%	 [Design 1/1, Contrast 3/3, Shuffling 432/500, Modality 1/1]
# 95.5%	 [Design 1/1, Contrast 3/3, Shuffling 433/500, Modality 1/1]
# 95.6%	 [Design 1/1, Contrast 3/3, Shuffling 434/500, Modality 1/1]
# 95.7%	 [Design 1/1, Contrast 3/3, Shuffling 435/500, Modality 1/1]
# 95.7%	 [Design 1/1, Contrast 3/3, Shuffling 436/500, Modality 1/1]
# 95.8%	 [Design 1/1, Contrast 3/3, Shuffling 437/500, Modality 1/1]
# 95.9%	 [Design 1/1, Contrast 3/3, Shuffling 438/500, Modality 1/1]
# 95.9%	 [Design 1/1, Contrast 3/3, Shuffling 439/500, Modality 1/1]
# 96%	 [Design 1/1, Contrast 3/3, Shuffling 440/500, Modality 1/1]
# 96.1%	 [Design 1/1, Contrast 3/3, Shuffling 441/500, Modality 1/1]
# 96.1%	 [Design 1/1, Contrast 3/3, Shuffling 442/500, Modality 1/1]
# 96.2%	 [Design 1/1, Contrast 3/3, Shuffling 443/500, Modality 1/1]
# 96.3%	 [Design 1/1, Contrast 3/3, Shuffling 444/500, Modality 1/1]
# 96.3%	 [Design 1/1, Contrast 3/3, Shuffling 445/500, Modality 1/1]
# 96.4%	 [Design 1/1, Contrast 3/3, Shuffling 446/500, Modality 1/1]
# 96.5%	 [Design 1/1, Contrast 3/3, Shuffling 447/500, Modality 1/1]
# 96.5%	 [Design 1/1, Contrast 3/3, Shuffling 448/500, Modality 1/1]
# 96.6%	 [Design 1/1, Contrast 3/3, Shuffling 449/500, Modality 1/1]
# 96.7%	 [Design 1/1, Contrast 3/3, Shuffling 450/500, Modality 1/1]
# 96.7%	 [Design 1/1, Contrast 3/3, Shuffling 451/500, Modality 1/1]
# 96.8%	 [Design 1/1, Contrast 3/3, Shuffling 452/500, Modality 1/1]
# 96.9%	 [Design 1/1, Contrast 3/3, Shuffling 453/500, Modality 1/1]
# 96.9%	 [Design 1/1, Contrast 3/3, Shuffling 454/500, Modality 1/1]
# 97%	 [Design 1/1, Contrast 3/3, Shuffling 455/500, Modality 1/1]
# 97.1%	 [Design 1/1, Contrast 3/3, Shuffling 456/500, Modality 1/1]
# 97.1%	 [Design 1/1, Contrast 3/3, Shuffling 457/500, Modality 1/1]
# 97.2%	 [Design 1/1, Contrast 3/3, Shuffling 458/500, Modality 1/1]
# 97.3%	 [Design 1/1, Contrast 3/3, Shuffling 459/500, Modality 1/1]
# 97.3%	 [Design 1/1, Contrast 3/3, Shuffling 460/500, Modality 1/1]
# 97.4%	 [Design 1/1, Contrast 3/3, Shuffling 461/500, Modality 1/1]
# 97.5%	 [Design 1/1, Contrast 3/3, Shuffling 462/500, Modality 1/1]
# 97.5%	 [Design 1/1, Contrast 3/3, Shuffling 463/500, Modality 1/1]
# 97.6%	 [Design 1/1, Contrast 3/3, Shuffling 464/500, Modality 1/1]
# 97.7%	 [Design 1/1, Contrast 3/3, Shuffling 465/500, Modality 1/1]
# 97.7%	 [Design 1/1, Contrast 3/3, Shuffling 466/500, Modality 1/1]
# 97.8%	 [Design 1/1, Contrast 3/3, Shuffling 467/500, Modality 1/1]
# 97.9%	 [Design 1/1, Contrast 3/3, Shuffling 468/500, Modality 1/1]
# 97.9%	 [Design 1/1, Contrast 3/3, Shuffling 469/500, Modality 1/1]
# 98%	 [Design 1/1, Contrast 3/3, Shuffling 470/500, Modality 1/1]
# 98.1%	 [Design 1/1, Contrast 3/3, Shuffling 471/500, Modality 1/1]
# 98.1%	 [Design 1/1, Contrast 3/3, Shuffling 472/500, Modality 1/1]
# 98.2%	 [Design 1/1, Contrast 3/3, Shuffling 473/500, Modality 1/1]
# 98.3%	 [Design 1/1, Contrast 3/3, Shuffling 474/500, Modality 1/1]
# 98.3%	 [Design 1/1, Contrast 3/3, Shuffling 475/500, Modality 1/1]
# 98.4%	 [Design 1/1, Contrast 3/3, Shuffling 476/500, Modality 1/1]
# 98.5%	 [Design 1/1, Contrast 3/3, Shuffling 477/500, Modality 1/1]
# 98.5%	 [Design 1/1, Contrast 3/3, Shuffling 478/500, Modality 1/1]
# 98.6%	 [Design 1/1, Contrast 3/3, Shuffling 479/500, Modality 1/1]
# 98.7%	 [Design 1/1, Contrast 3/3, Shuffling 480/500, Modality 1/1]
# 98.7%	 [Design 1/1, Contrast 3/3, Shuffling 481/500, Modality 1/1]
# 98.8%	 [Design 1/1, Contrast 3/3, Shuffling 482/500, Modality 1/1]
# 98.9%	 [Design 1/1, Contrast 3/3, Shuffling 483/500, Modality 1/1]
# 98.9%	 [Design 1/1, Contrast 3/3, Shuffling 484/500, Modality 1/1]
# 99%	 [Design 1/1, Contrast 3/3, Shuffling 485/500, Modality 1/1]
# 99.1%	 [Design 1/1, Contrast 3/3, Shuffling 486/500, Modality 1/1]
# 99.1%	 [Design 1/1, Contrast 3/3, Shuffling 487/500, Modality 1/1]
# 99.2%	 [Design 1/1, Contrast 3/3, Shuffling 488/500, Modality 1/1]
# 99.3%	 [Design 1/1, Contrast 3/3, Shuffling 489/500, Modality 1/1]
# 99.3%	 [Design 1/1, Contrast 3/3, Shuffling 490/500, Modality 1/1]
# 99.4%	 [Design 1/1, Contrast 3/3, Shuffling 491/500, Modality 1/1]
# 99.5%	 [Design 1/1, Contrast 3/3, Shuffling 492/500, Modality 1/1]
# 99.5%	 [Design 1/1, Contrast 3/3, Shuffling 493/500, Modality 1/1]
# 99.6%	 [Design 1/1, Contrast 3/3, Shuffling 494/500, Modality 1/1]
# 99.7%	 [Design 1/1, Contrast 3/3, Shuffling 495/500, Modality 1/1]
# 99.7%	 [Design 1/1, Contrast 3/3, Shuffling 496/500, Modality 1/1]
# 99.8%	 [Design 1/1, Contrast 3/3, Shuffling 497/500, Modality 1/1]
# 99.9%	 [Design 1/1, Contrast 3/3, Shuffling 498/500, Modality 1/1]
# 99.9%	 [Design 1/1, Contrast 3/3, Shuffling 499/500, Modality 1/1]
# 100%	 [Design 1/1, Contrast 3/3, Shuffling 500/500, Modality 1/1]
# Elapsed time with permutations: ~ 4435.86 seconds.
# Computing p-values.
# Saving p-values (uncorrected, and corrected within modality and within contrast).
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_dpv_tstat_uncp_c1
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_dpv_tstat_fwep_c1
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_c1
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_uncp_c1
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_fwep_c1
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_dpv_tstat_uncp_c2
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_dpv_tstat_fwep_c2
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_c2
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_uncp_c2
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_fwep_c2
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_dpv_tstat_uncp_c3
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_dpv_tstat_fwep_c3
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_c3
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_uncp_c3
# 	 Saving file: /data/fastfmri_toolbox_test_data/3T/bids/derivatives/TEST_PALM_CIFTI/sub-002_ses-02/frequency-02_CortexRight_tfce_tstat_fwep_c3
# Elapsed time generating and saving results: ~ 0.371911 seconds.
# Overall elapsed time: ~ 4439.14 seconds.
# PALM finished at 06-Jun-2023 18:23:11.

# %%
# !chmod -R 777 {out_dir}

# %%
# !rm -rf {out_dir} /tmp/*

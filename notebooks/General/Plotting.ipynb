# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import sys

sys.path.append('/opt/app')
from fastfmri_toolbox.visualize.base import PlotSlices
# Out:
# <style>.container { width:100% !important; }</style>

# %%
nifti_path = "/data/fastfmri_toolbox_test_data/oscprep_fmapless/smriprep/sub-000/ses-Localizer/anat/sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-preproc_T1w.nii.gz"
mask_path = "/data/fastfmri_toolbox_test_data/oscprep_fmapless/smriprep/sub-000/ses-Localizer/anat/sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-brain_mask.nii.gz"

plotter = PlotSlices(nifti_path, n_cols=12)
plotter.plot_base()
plotter.add_contours(mask_path,c='cyan',lw=1.)

# %%
# !ls /data/fastfmri_toolbox_test_data/oscprep_fmapless/smriprep/sub-000/ses-Localizer/anat
# Out:
# sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-aparcaseg_dseg.nii.gz
# sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-aseg_dseg.nii.gz
# sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-brain_dseg.nii.gz
# sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-brain_mask.json
# sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-brain_mask.nii.gz
# sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-preproc_T1w.json
# sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-preproc_T1w.nii.gz
# sub-000_ses-Localizer_acq-MPRAGE_run-01_desc-ribbon_mask.nii.gz
# sub-000_ses-Localizer_acq-MPRAGE_run-01_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5
# sub-000_ses-Localizer_acq-MPRAGE_run-01_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5
# sub-000_ses-Localizer_acq-MPRAGE_run-01_from-T1w_to-fsnative_mode-image_xfm.txt
# sub-000_ses-Localizer_acq-MPRAGE_run-01_from-fsnative_to-T1w_mode-image_xfm.txt
# sub-000_ses-Localizer_acq-MPRAGE_run-01_hemi-L_curv.shape.gii
# ...

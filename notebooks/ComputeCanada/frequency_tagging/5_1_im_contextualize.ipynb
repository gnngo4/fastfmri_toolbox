# %%
import itertools
import nibabel as nib
import numpy as np
import time
import pickle

from collections import defaultdict
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
from sklearn.metrics import roc_curve, auc

import sys
sys.path.append("ComputeCanada/frequency_tagging")
from utils import (
    get_roi_colour_codes,
    extract_im_products,
    get_frequency_text_codes,
    change_font,
    SCRATCH_DIR,
    MAIN
)
sys.path.append("/opt/app/scripts")
from im_sc_utils import (
    get_binary_paths,
    convert_multimap_to_fo_maps,
    process_maps,
    compute_metrics,
    generate_surrogates,
    convert_array_to_top_n_values,
    compute_metrics_over_surrogates,
    contains_only_0_1,
    area_under_curve,
    add_data_to_dict,
    N_VERTICES_AFTER_RESAMPLING,
    GEODESIC_LH,
    GEODESIC_RH,
    DSCALAR_TEMPLATE,
)
change_font()

# Directories
surrogatedir = SCRATCH_DIR / "surrogate_maps"
if not surrogatedir.exists():
    surrogatedir.mkdir(exist_ok=True, parents=True)
pickledir = surrogatedir / "pickles"
if not pickledir.exists():
    pickledir.mkdir(exist_ok=True, parents=True)
null_auc_dir = surrogatedir / "null_auc"
if not null_auc_dir.exists():
    null_auc_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Run surrogate map generation and metric calculation over all surrogate maps

# %%
CONTAINER = '/project/def-mmur/gngo4/containers/neuroimaging-notebook-v2.simg'
main_scripts_dir = Path("/data/scripts/04_im_sc")

experiment_id = "1_frequency_tagging"
mri_id = "3T"
sub_ids = ["000","002","003","004","006","005","007","008","009"] # First 5 and last 4 are stimulated right visual field and left visual field, respectively
roi_task_ids = ["control","entrain"]
f1, f2 = (.125, .2)
corr_types = ["uncp","fdrp"]
constant_fo = .8
fo_spacing = .05
N_SURROGATES = 1000
for sub_id, roi_task_id, corr_type in itertools.product(sub_ids, roi_task_ids, corr_types):
    im_frequencies = extract_im_products(f1, f2)
    for im_str, fim in im_frequencies.items():
        out_lh_surrogate_dir = surrogatedir / f"experiment-{experiment_id}_mri-{mri_id}_sub-{sub_id}_roi-task-{roi_task_id}_p-{corr_type}_im-{im_str}_n-{N_SURROGATES}_hemi-lh"
        out_rh_surrogate_dir = surrogatedir / f"experiment-{experiment_id}_mri-{mri_id}_sub-{sub_id}_roi-task-{roi_task_id}_p-{corr_type}_im-{im_str}_n-{N_SURROGATES}_hemi-rh"
        out_null_auc_pkl = null_auc_dir / f"experiment-{experiment_id}_mri-{mri_id}_sub-{sub_id}_roi-task-{roi_task_id}_p-{corr_type}_im-{im_str}_n-{N_SURROGATES}_null_auc.pkl"
        if all([out_lh_surrogate_dir.exists(), out_rh_surrogate_dir.exists(), out_null_auc_pkl.exists()]):
            print(f"Skipping {sub_id}, {roi_task_id}, {im_str}, {corr_type}")
            continue
        txt = f"""#!/bin/bash
module load apptainer/1.2.4

singularity run \\
--bind /project/def-mmur/gngo4/data/fastfmri:/data \\
--bind /scratch/gngo4:/scratch \\
--bind /project/def-mmur/gngo4/projects/fastfmri_toolbox:/opt/app \\
{CONTAINER} \\
python3 /opt/app/scripts/im_sc.py \\
{experiment_id} \\
{mri_id} \\
{sub_id} \\
{roi_task_id} \\
{im_str} \\
{f1} \\
{f2} \\
{fim} \\
{corr_type} \\
--constant-fo {constant_fo} \\
--fo-spacing {fo_spacing}
        """
        cmd_path = f"{main_scripts_dir}/experiment-{experiment_id}_mri-{mri_id}_sub-{sub_id}_roi-{roi_task_id}_im-{im_str}_f1-{f1}_f2-{f2}_fim-{fim}_corr-{corr_type}.sh"
        print(cmd_path)
        with open(cmd_path, 'w') as f:
            f.write(txt)
# Out:
# Skipping 000, control, f1, uncp
# Skipping 000, control, f2, uncp
# Skipping 000, control, f2-f1, uncp
# Skipping 000, control, f1+f2, uncp
# Skipping 000, control, 2f1, uncp
# Skipping 000, control, 2f2, uncp
# Skipping 000, control, 2f1-f2, uncp
# Skipping 000, control, 2f2-f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-control_im-f1_f1-0.125_f2-0.2_fim-0.125_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-control_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-control_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 000, control, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 000, entrain, f1, uncp
# Skipping 000, entrain, f2, uncp
# Skipping 000, entrain, f2-f1, uncp
# Skipping 000, entrain, f1+f2, uncp
# Skipping 000, entrain, 2f1, uncp
# Skipping 000, entrain, 2f2, uncp
# Skipping 000, entrain, 2f1-f2, uncp
# Skipping 000, entrain, 2f2-f1, uncp
# Skipping 000, entrain, f1, fdrp
# Skipping 000, entrain, f2, fdrp
# Skipping 000, entrain, f2-f1, fdrp
# Skipping 000, entrain, f1+f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-entrain_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-entrain_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-000_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 002, control, f1, uncp
# Skipping 002, control, f2, uncp
# Skipping 002, control, f2-f1, uncp
# Skipping 002, control, f1+f2, uncp
# Skipping 002, control, 2f1, uncp
# Skipping 002, control, 2f2, uncp
# Skipping 002, control, 2f1-f2, uncp
# Skipping 002, control, 2f2-f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-control_im-f1_f1-0.125_f2-0.2_fim-0.125_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# Skipping 002, control, f2-f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-control_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 002, control, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 002, entrain, f1, uncp
# Skipping 002, entrain, f2, uncp
# Skipping 002, entrain, f2-f1, uncp
# Skipping 002, entrain, f1+f2, uncp
# Skipping 002, entrain, 2f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-uncp.sh
# Skipping 002, entrain, 2f1-f2, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-uncp.sh
# Skipping 002, entrain, f1, fdrp
# Skipping 002, entrain, f2, fdrp
# Skipping 002, entrain, f2-f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-entrain_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-entrain_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 002, entrain, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-002_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 003, control, f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-uncp.sh
# Skipping 003, control, f2-f1, uncp
# Skipping 003, control, f1+f2, uncp
# Skipping 003, control, 2f1, uncp
# Skipping 003, control, 2f2, uncp
# Skipping 003, control, 2f1-f2, uncp
# Skipping 003, control, 2f2-f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-f1_f1-0.125_f2-0.2_fim-0.125_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 003, entrain, f1, uncp
# Skipping 003, entrain, f2, uncp
# Skipping 003, entrain, f2-f1, uncp
# Skipping 003, entrain, f1+f2, uncp
# Skipping 003, entrain, 2f1, uncp
# Skipping 003, entrain, 2f2, uncp
# Skipping 003, entrain, 2f1-f2, uncp
# Skipping 003, entrain, 2f2-f1, uncp
# Skipping 003, entrain, f1, fdrp
# Skipping 003, entrain, f2, fdrp
# Skipping 003, entrain, f2-f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-entrain_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# Skipping 003, entrain, 2f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 003, entrain, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-003_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 004, control, f1, uncp
# Skipping 004, control, f2, uncp
# Skipping 004, control, f2-f1, uncp
# Skipping 004, control, f1+f2, uncp
# Skipping 004, control, 2f1, uncp
# Skipping 004, control, 2f2, uncp
# Skipping 004, control, 2f1-f2, uncp
# Skipping 004, control, 2f2-f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-control_im-f1_f1-0.125_f2-0.2_fim-0.125_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-control_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# Skipping 004, control, f1+f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 004, control, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 004, entrain, f1, uncp
# Skipping 004, entrain, f2, uncp
# Skipping 004, entrain, f2-f1, uncp
# Skipping 004, entrain, f1+f2, uncp
# Skipping 004, entrain, 2f1, uncp
# Skipping 004, entrain, 2f2, uncp
# Skipping 004, entrain, 2f1-f2, uncp
# Skipping 004, entrain, 2f2-f1, uncp
# Skipping 004, entrain, f1, fdrp
# Skipping 004, entrain, f2, fdrp
# Skipping 004, entrain, f2-f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-entrain_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-entrain_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 004, entrain, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-004_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 006, control, f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-uncp.sh
# Skipping 006, control, f2-f1, uncp
# Skipping 006, control, f1+f2, uncp
# Skipping 006, control, 2f1, uncp
# Skipping 006, control, 2f2, uncp
# Skipping 006, control, 2f1-f2, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-uncp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-f1_f1-0.125_f2-0.2_fim-0.125_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 006, entrain, f1, uncp
# Skipping 006, entrain, f2, uncp
# Skipping 006, entrain, f2-f1, uncp
# Skipping 006, entrain, f1+f2, uncp
# Skipping 006, entrain, 2f1, uncp
# Skipping 006, entrain, 2f2, uncp
# Skipping 006, entrain, 2f1-f2, uncp
# Skipping 006, entrain, 2f2-f1, uncp
# Skipping 006, entrain, f1, fdrp
# Skipping 006, entrain, f2, fdrp
# Skipping 006, entrain, f2-f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-entrain_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-entrain_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 006, entrain, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-006_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 005, control, f1, uncp
# Skipping 005, control, f2, uncp
# Skipping 005, control, f2-f1, uncp
# Skipping 005, control, f1+f2, uncp
# Skipping 005, control, 2f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-uncp.sh
# Skipping 005, control, 2f1-f2, uncp
# Skipping 005, control, 2f2-f1, uncp
# Skipping 005, control, f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 005, entrain, f1, uncp
# Skipping 005, entrain, f2, uncp
# Skipping 005, entrain, f2-f1, uncp
# Skipping 005, entrain, f1+f2, uncp
# Skipping 005, entrain, 2f1, uncp
# Skipping 005, entrain, 2f2, uncp
# Skipping 005, entrain, 2f1-f2, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-uncp.sh
# Skipping 005, entrain, f1, fdrp
# Skipping 005, entrain, f2, fdrp
# Skipping 005, entrain, f2-f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-entrain_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# Skipping 005, entrain, 2f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-entrain_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-005_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 007, control, f1, uncp
# Skipping 007, control, f2, uncp
# Skipping 007, control, f2-f1, uncp
# Skipping 007, control, f1+f2, uncp
# Skipping 007, control, 2f1, uncp
# Skipping 007, control, 2f2, uncp
# Skipping 007, control, 2f1-f2, uncp
# Skipping 007, control, 2f2-f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-control_im-f1_f1-0.125_f2-0.2_fim-0.125_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-control_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# Skipping 007, control, f1+f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 007, control, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 007, entrain, f1, uncp
# Skipping 007, entrain, f2, uncp
# Skipping 007, entrain, f2-f1, uncp
# Skipping 007, entrain, f1+f2, uncp
# Skipping 007, entrain, 2f1, uncp
# Skipping 007, entrain, 2f2, uncp
# Skipping 007, entrain, 2f1-f2, uncp
# Skipping 007, entrain, 2f2-f1, uncp
# Skipping 007, entrain, f1, fdrp
# Skipping 007, entrain, f2, fdrp
# Skipping 007, entrain, f2-f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-entrain_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-entrain_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-entrain_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-007_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 008, control, f1, uncp
# Skipping 008, control, f2, uncp
# Skipping 008, control, f2-f1, uncp
# Skipping 008, control, f1+f2, uncp
# Skipping 008, control, 2f1, uncp
# Skipping 008, control, 2f2, uncp
# Skipping 008, control, 2f1-f2, uncp
# Skipping 008, control, 2f2-f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_im-f1_f1-0.125_f2-0.2_fim-0.125_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 008, entrain, f1, uncp
# Skipping 008, entrain, f2, uncp
# Skipping 008, entrain, f2-f1, uncp
# Skipping 008, entrain, f1+f2, uncp
# Skipping 008, entrain, 2f1, uncp
# Skipping 008, entrain, 2f2, uncp
# Skipping 008, entrain, 2f1-f2, uncp
# Skipping 008, entrain, 2f2-f1, uncp
# Skipping 008, entrain, f1, fdrp
# Skipping 008, entrain, f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-entrain_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-entrain_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-entrain_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-entrain_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-008_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 009, control, f1, uncp
# Skipping 009, control, f2, uncp
# Skipping 009, control, f2-f1, uncp
# Skipping 009, control, f1+f2, uncp
# Skipping 009, control, 2f1, uncp
# Skipping 009, control, 2f2, uncp
# Skipping 009, control, 2f1-f2, uncp
# Skipping 009, control, 2f2-f1, uncp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-control_im-f1_f1-0.125_f2-0.2_fim-0.125_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-control_im-f2_f1-0.125_f2-0.2_fim-0.2_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-control_im-f2-f1_f1-0.125_f2-0.2_fim-0.075_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-control_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-control_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-control_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# Skipping 009, control, 2f1-f2, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-control_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh
# Skipping 009, entrain, f1, uncp
# Skipping 009, entrain, f2, uncp
# Skipping 009, entrain, f2-f1, uncp
# Skipping 009, entrain, f1+f2, uncp
# Skipping 009, entrain, 2f1, uncp
# Skipping 009, entrain, 2f2, uncp
# Skipping 009, entrain, 2f1-f2, uncp
# Skipping 009, entrain, 2f2-f1, uncp
# Skipping 009, entrain, f1, fdrp
# Skipping 009, entrain, f2, fdrp
# Skipping 009, entrain, f2-f1, fdrp
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-entrain_im-f1+f2_f1-0.125_f2-0.2_fim-0.325_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-entrain_im-2f1_f1-0.125_f2-0.2_fim-0.25_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-entrain_im-2f2_f1-0.125_f2-0.2_fim-0.4_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-entrain_im-2f1-f2_f1-0.125_f2-0.2_fim-0.05_corr-fdrp.sh
# /data/scripts/04_im_sc/experiment-1_frequency_tagging_mri-3T_sub-009_roi-entrain_im-2f2-f1_f1-0.125_f2-0.2_fim-0.275_corr-fdrp.sh

# %% [markdown]
# Run

# %% [markdown]
# Store data of spatial association between (a) im maps to (b) f1 only, f2 only, f1, f2, f1&f2 and f1&f2 (2 mm dilated)
# - general info of the roi
#     - experiment_id # 3T_CONTROL, 3T, 7T, 3T_VARY, 7T_VARY
#     - sub_id
#     - f1
#     - f2
#     - roi_task_id
#     - {a} # f1, f2, f2-f1, f1+f2, 2f1, 2f2, 2f1-f2, 2f2-f1
#     - corr_type # uncp, fdrp
# - metrics, how well each roi matches to (b)
#     - {b}_dice
#     - {b}_dice_p_value
#     - {b}_jaccard
#     - {b}_jaccard_p_value
#     - {b}_auc
#     - {b}_auc_p_value

# %%
# Global params
for i in [GEODESIC_LH, GEODESIC_RH, DSCALAR_TEMPLATE]:
    assert Path(i).exists(), f"{i} not found."
STR_DICT = {
    "IM": "$f_{im}$",
    "f1_only": "$f_1$ only",
    "f2_only": "$f_2$ only",
    "f1": "$f_1$",
    "f2": "$f_2$",
    "f1&f2": "$f_1 \cap f_2$",
    "f1&f2_dil2mm": "$f_1 \cap f_2$\n(2mm dilated)",
}

# Input
constant_fo = .8
fo_spacing = .05
corr_type = "uncp"
N_SURROGATES = 1000

# Plotting
mosaic = ["IM","f1_only","f2_only","f1","f2","f1&f2","f1&f2_dil2mm"]
FONTSIZE = 6
FIG_ON = False

# Start timer
start_time = time.time()

# Level 1
_experiment_ids = ["3TControl"] * 9 + ["3T"] * 9 + ["7T"] * 4 + ["3TVary"] * 6 + ["7TVary"] * 6 # This is the experiment label in the df
experiment_ids = ["1_frequency_tagging"] * 18 + ["1_attention"] * 4 + ["1_frequency_tagging"] * 12
mri_ids = ["3T"] * 18 + ["7T"] * 4 + ["3T"] * 6 + ["7T"] * 6
roi_task_ids = ["control"] * 9 + ["entrain"] * 9 + ["AttendAway"] * 4 + [f"entrain{i}" for i in ["A", "B", "C", "D", "E", "F"]] * 2
sub_ids = ["000","002","003","004","005","006","007","008","009"] * 2 + ["Pilot001","Pilot009","Pilot010","Pilot011"] + ["020"] * 3 + ["021"] * 3 + ["020"] * 3 + ["021"] * 3
frequencies = [(.125,.2)]*18 + [(.125,.2)]*4 + [(.125,.2),(.125,.175),(.125,.15),(.125,.2),(.15,.2),(.175,.2)] * 2

df = None
for _experiment_id, experiment_id, mri_id, roi_task_id, sub_id, (f1,f2) in zip(_experiment_ids, experiment_ids, mri_ids, roi_task_ids, sub_ids, frequencies):
    
    im_strs = [i for i in extract_im_products(f1,f2).keys()]
    fims = [i for i in extract_im_products(f1,f2).values()]

    df_pickle_path = pickledir / f"experiment-{experiment_id}_mri-{mri_id}_sub-{sub_id}_roi-{roi_task_id}_corr-{corr_type}.pkl"
    if df_pickle_path.exists():
        print(f"Loading [{experiment_id}, {mri_id}, {sub_id}, {roi_task_id}, {corr_type}, {f1}, {f2}]: {df_pickle_path}")
        if df is None:
            df = pd.read_pickle(df_pickle_path)
        else:
            df = pd.concat((df, pd.read_pickle(df_pickle_path)))
        continue
        
    print(f"Generating pickle [{experiment_id}, {mri_id}, {sub_id}, {roi_task_id}, {corr_type}, {f1}, {f2}]: {df_pickle_path}")
    data_dict = None
    for im_str, fim in zip(im_strs, fims):

        print(f"Subject: {sub_id}, {im_str} [{fim}]")

        # Get all paths for analysis
        path_dict = get_binary_paths(experiment_id, mri_id, sub_id, roi_task_id, f1, f2, fim, corr_type)

        # Get FO maps for f1, f2, f_im, an whole brain mask
        fo_maps = convert_multimap_to_fo_maps(path_dict, dscalar_template=DSCALAR_TEMPLATE)

        # Process whole brain mask
        wb_coverage_mask = (fo_maps['mask'] == 1).astype(int)
        mask_coords = wb_coverage_mask == 1 # Coordinates

        # Generate f_im map (ground truth)
        im_roi = (fo_maps["f_im"] >= constant_fo).astype(int)
        # Generate predicted maps under the same conditions as the ground truth ROI, then compute dice and jaccard metrics
        dice_metrics = {}
        jaccard_metrics = {}
        constant_all_rois = process_maps(fo_maps, constant_fo)
        for k, v in constant_all_rois.items():
            metrics = compute_metrics(im_roi[mask_coords], v[mask_coords])
            dice_metrics[k] = metrics["dice"]
            jaccard_metrics[k] = metrics["jaccard"]
        # Get n vertices for task IM per hemi
        N_LH = im_roi[:N_VERTICES_AFTER_RESAMPLING].sum()
        N_RH = im_roi[N_VERTICES_AFTER_RESAMPLING:].sum()
        if N_LH + N_RH == 0:
            print("WARNING: No vertices found in the ROI.")
            continue

        # Generate SA-preserved surrogate maps of f_im fractional overlap maps
        basename = f"experiment-{experiment_id}_mri-{mri_id}_sub-{sub_id}_roi-task-{roi_task_id}_p-{corr_type}_im-{im_str}_n-{N_SURROGATES}"
        lh_surrogate_maps = generate_surrogates(fo_maps["f_im"], wb_coverage_mask, "lh", surrogatedir, basename, n_surrogates=N_SURROGATES)
        rh_surrogate_maps = generate_surrogates(fo_maps["f_im"], wb_coverage_mask, "rh", surrogatedir, basename, n_surrogates=N_SURROGATES)
        # Binarize surrogate maps
        for i in range(N_SURROGATES):
            lh_surrogate_map = convert_array_to_top_n_values(lh_surrogate_maps[i,:], N_LH)
            rh_surrogate_map = convert_array_to_top_n_values(rh_surrogate_maps[i,:], N_RH)
            if i == 0:
                surrogate_maps = np.concatenate((lh_surrogate_map, rh_surrogate_map)).astype(int)
            else:
                surrogate_maps = np.vstack((surrogate_maps, np.concatenate((lh_surrogate_map, rh_surrogate_map)).astype(int)))

        # Generate iid binary maps of f_im fractional overlap maps
        iid_maps = np.zeros_like(surrogate_maps)
        for i in range(N_SURROGATES):
            for hemi, n_vertices, hemi_mask_coords in zip(
                ["lh","rh"],
                [N_LH, N_RH],
                [mask_coords[:N_VERTICES_AFTER_RESAMPLING], mask_coords[N_VERTICES_AFTER_RESAMPLING:]]
            ):  
                indices = np.random.choice(hemi_mask_coords.sum(), n_vertices, replace=False)
                if hemi == "lh":
                    sub_iid_maps = iid_maps[i,:N_VERTICES_AFTER_RESAMPLING][hemi_mask_coords]
                    sub_iid_maps[indices] = 1
                    iid_maps[i,:N_VERTICES_AFTER_RESAMPLING][hemi_mask_coords] = sub_iid_maps
                elif hemi == "rh":
                    sub_iid_maps = iid_maps[i,N_VERTICES_AFTER_RESAMPLING:][hemi_mask_coords]
                    sub_iid_maps[indices] = 1
                    iid_maps[i,N_VERTICES_AFTER_RESAMPLING:][hemi_mask_coords] = sub_iid_maps
                else:
                    raise ValueError(f"{hemi} not supported.")

        # Instantiate tpr and fpr dictionaries
        tpr_dict = defaultdict(list)
        fpr_dict = defaultdict(list)

        # Loop over `fo_range` to obtain ROC-curves
        fo_range = np.arange(0, 1+fo_spacing, fo_spacing)
        for fo in fo_range:

            # Generate all maps used to assess spatial overlap with f_im
            all_rois = process_maps(fo_maps,fo)
            predicted_im_roi = all_rois["IM"]
            f1_roi = all_rois["f1"]
            f2_roi = all_rois["f2"]
            f1_f2_roi = all_rois["f1&f2"]
            f1_only_roi = all_rois["f1_only"]
            f2_only_roi = all_rois["f2_only"]
            f1_f2_dil_2mm_roi = all_rois["f1&f2_dil2mm"]

            # Check & verbose
            for roi_str, _roi in zip(
                ["Surrogates",f"IM {im_str}", "f1", "f2", "f1 & f2", "f1 only", "f2 only", "f1 & f2 (dilate 2mm)"],
                [surrogate_maps, predicted_im_roi, f1_roi, f2_roi, f1_f2_roi, f1_only_roi, f2_only_roi, f1_f2_dil_2mm_roi]
            ):
                roi_shape_idx = 0
                if len(_roi.shape) == 2:
                    roi_shape_idx = 1
                assert contains_only_0_1(_roi), f"Unique values in roi: {np.unique(_roi)}"
                assert _roi.shape[roi_shape_idx] == N_VERTICES_AFTER_RESAMPLING * 2, f"Expected vertex count: {N_VERTICES_AFTER_RESAMPLING * 2} [{_roi.shape[roi_shape_idx]}]"

            all_rois = [predicted_im_roi,f1_only_roi,f2_only_roi,f1_roi,f2_roi,f1_f2_roi,f1_f2_dil_2mm_roi]
            # Fill TPR and FPR list for all ROIs
            for roi_str, _roi in zip(mosaic, all_rois):
                im_labels = im_roi[mask_coords] # Ground truth
                predicted_labels = _roi[mask_coords] # Predicted
                fpr, tpr, _ = roc_curve(im_labels, predicted_labels)
                tpr_dict[roi_str].append(tpr[1])
                fpr_dict[roi_str].append(fpr[1])

        # Compute metrics over surrogates
        # Instantiate surrogate metrics
        iid_dice_metrics = {}
        surrogate_dice_metrics = {}
        iid_jaccard_metrics = {}
        surrogate_jaccard_metrics = {}
        iid_auc_metrics = defaultdict(list)
        surrogate_auc_metrics = defaultdict(list)
        # Compute dice and jaccard
        for k, v in constant_all_rois.items():
            iid_metrics = compute_metrics_over_surrogates(iid_maps, v, mask_coords)
            surrogate_metrics = compute_metrics_over_surrogates(surrogate_maps, v, mask_coords)
            iid_dice_metrics[k] = iid_metrics["dice"]
            iid_jaccard_metrics[k] = iid_metrics["jaccard"]
            surrogate_dice_metrics[k] = surrogate_metrics["dice"]
            surrogate_jaccard_metrics[k] = surrogate_metrics["jaccard"]
        # Compute auc for each surrogate map 
        # Loop over `fo_range` to obtain ROC-curves
        null_auc_pkl = null_auc_dir / f"{basename}_null_auc.pkl"
        if null_auc_pkl.exists():
            with open(null_auc_pkl, 'rb') as f:
                null_auc_arr = pickle.load(f)
            iid_auc_metrics = null_auc_arr["iid"]
            surrogate_auc_metrics = null_auc_arr["surrogate"]
        else:
            raise ValueError(f"{null_auc_pkl} does not exist. Run sbatch scripts.")
        # Plot
        fig, ax_dict = plt.subplot_mosaic([mosaic], figsize=(3.5,.5),dpi=600,layout="constrained")

        auc_metrics = {}
        for roi_str in mosaic:
            ax = ax_dict[roi_str]
            tpr_list = tpr_dict[roi_str]
            fpr_list = fpr_dict[roi_str]
            roc_auc = area_under_curve(fpr_list, tpr_list)
            auc_metrics[roi_str] = roc_auc # store auc metric
            ax.plot(fpr_list, tpr_list, color='r', lw=.5, zorder=2)
            ax.plot([0,1], [0,1], color='k', lw=.5, linestyle='--',zorder=1)
            ax.set_xlim([-.05, 1.05])
            ax.set_ylim([-.05, 1.05])
            ax.set_xlabel('FPR',fontsize=FONTSIZE-2)
            ax.set_ylabel('TPR',fontsize=FONTSIZE-2)
            if isinstance(roc_auc,float):
                roc_auc = f"{roc_auc:.2f}"
            updated_roi_str = STR_DICT[roi_str]
            ax.set_title(f"{updated_roi_str} [{roc_auc}]",fontsize=FONTSIZE-2)
            for _spine in ["top", "right", "left", "bottom"]:
                ax.spines[_spine].set_visible(False)
            ax.set_xticks([])
            ax.set_yticks([])
        if not FIG_ON:
            plt.close()

        # Plot p-value plots for each subject
        fig, ax_dict = plt.subplot_mosaic(
            [
                [f"dice_{i}" for i in mosaic],
                [f"jaccard_{i}" for i in mosaic],
                [f"auc_{i}" for i in mosaic],
            ],
            figsize=(7,3),
            dpi=600,
            layout="constrained"
        )

        iid_metric_dict = {
            "dice": iid_dice_metrics,
            "jaccard": iid_jaccard_metrics,
            "auc": iid_auc_metrics,
        }
        surrogate_metric_dict = {
            "dice": surrogate_dice_metrics,
            "jaccard": surrogate_jaccard_metrics,
            "auc": surrogate_auc_metrics,
        }
        metric_dict = {
            "dice": dice_metrics,
            "jaccard": jaccard_metrics,
            "auc": auc_metrics,
        }

        surrogate_p_value_dict = {
            "dice": {},
            "jaccard": {},
            "auc": {},
        }

        # Plot and also store p-value in `surrogate_p_value_dict`
        n_bins = 10

        for _str, ax in ax_dict.items():
            roi_str = '_'.join(_str.split("_")[1:])
            metric_type = _str.split("_")[0]
            iid_metrics = iid_metric_dict[metric_type]
            surrogate_metrics = surrogate_metric_dict[metric_type]
            metric = metric_dict[metric_type]
            ax.hist(iid_metrics[roi_str],bins=n_bins,color='darkred',zorder=2, alpha=1., width=.01)
            ax.hist(surrogate_metrics[roi_str],bins=n_bins,color='lightblue',zorder=1, alpha=1., width=.01)
            ax.axvline(x=metric[roi_str],color="k",ls="-",lw=.5)
            # P-value estimation
            iid_p_value = (iid_metrics[roi_str]>metric[roi_str]).sum()/N_SURROGATES
            surrogate_p_value = (surrogate_metrics[roi_str]>metric[roi_str]).sum()/N_SURROGATES
            surrogate_p_value_dict[metric_type][roi_str] = surrogate_p_value
            for _spine in ["top", "right", "left"]:
                ax.spines[_spine].set_visible(False)
            ax.set_xticks([0,1.])
            ax.set_xticklabels([0,1.],fontsize=FONTSIZE)
            ax.set_xlim([0,1.])
            x_text_pos = ax.get_xlim()[-1]*.1
            ax.set_yticks([])
            ax.set_title(f"{STR_DICT[roi_str]}",fontsize=FONTSIZE)
            if roi_str == "IM":
                ax.set_ylabel(metric_type, fontsize=FONTSIZE)
            ax.text(x_text_pos, ax.get_ylim()[-1]*.7,f"$p$={iid_p_value:.3f}",fontsize=FONTSIZE,color="darkred")
            ax.text(x_text_pos, ax.get_ylim()[-1]*.5,f"$p$={surrogate_p_value:.3f}",fontsize=FONTSIZE,color="lightblue")
        if not FIG_ON:
            plt.close()

        data_dict = add_data_to_dict(_experiment_id, sub_id, roi_task_id, im_str, metric_dict, surrogate_p_value_dict, data_dict=data_dict)
        
    # Save
    sub_df = pd.DataFrame(data_dict)
    sub_df.to_pickle(df_pickle_path)
    if df is None:
        df = sub_df.copy()
    else:
        df = pd.concat((df, sub_df))
    print(df.shape)

# End timer
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed Time: {elapsed_time} seconds")
# Out:
# Loading [1_frequency_tagging, 3T, 000, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-000_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 002, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-002_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 003, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-003_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 004, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-004_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 005, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-005_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 006, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-006_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 007, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-007_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 008, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-008_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 009, control, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-009_roi-control_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 000, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-000_roi-entrain_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 002, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-002_roi-entrain_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 003, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-003_roi-entrain_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 004, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-004_roi-entrain_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 005, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-005_roi-entrain_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 006, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-006_roi-entrain_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 007, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-007_roi-entrain_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 008, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-008_roi-entrain_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 009, entrain, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-009_roi-entrain_corr-uncp.pkl
# Loading [1_attention, 7T, Pilot001, AttendAway, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_attention_mri-7T_sub-Pilot001_roi-AttendAway_corr-uncp.pkl
# Loading [1_attention, 7T, Pilot009, AttendAway, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_attention_mri-7T_sub-Pilot009_roi-AttendAway_corr-uncp.pkl
# Loading [1_attention, 7T, Pilot010, AttendAway, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_attention_mri-7T_sub-Pilot010_roi-AttendAway_corr-uncp.pkl
# Loading [1_attention, 7T, Pilot011, AttendAway, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_attention_mri-7T_sub-Pilot011_roi-AttendAway_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 020, entrainA, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-020_roi-entrainA_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 020, entrainB, uncp, 0.125, 0.175]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-020_roi-entrainB_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 020, entrainC, uncp, 0.125, 0.15]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-020_roi-entrainC_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 021, entrainD, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-021_roi-entrainD_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 021, entrainE, uncp, 0.15, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-021_roi-entrainE_corr-uncp.pkl
# Loading [1_frequency_tagging, 3T, 021, entrainF, uncp, 0.175, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-3T_sub-021_roi-entrainF_corr-uncp.pkl
# Loading [1_frequency_tagging, 7T, 020, entrainA, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-7T_sub-020_roi-entrainA_corr-uncp.pkl
# Loading [1_frequency_tagging, 7T, 020, entrainB, uncp, 0.125, 0.175]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-7T_sub-020_roi-entrainB_corr-uncp.pkl
# Loading [1_frequency_tagging, 7T, 020, entrainC, uncp, 0.125, 0.15]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-7T_sub-020_roi-entrainC_corr-uncp.pkl
# Loading [1_frequency_tagging, 7T, 021, entrainD, uncp, 0.125, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-7T_sub-021_roi-entrainD_corr-uncp.pkl
# Loading [1_frequency_tagging, 7T, 021, entrainE, uncp, 0.15, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-7T_sub-021_roi-entrainE_corr-uncp.pkl
# Loading [1_frequency_tagging, 7T, 021, entrainF, uncp, 0.175, 0.2]: /scratch/fastfmri/surrogate_maps/pickles/experiment-1_frequency_tagging_mri-7T_sub-021_roi-entrainF_corr-uncp.pkl
# Elapsed Time: 1.6429998874664307 seconds

# %% [markdown]
# - heatmap colours are metrics (dice, jaccard, auc)
#     - p >= .05 is grey
# - x-axis
#     - subjects
# - y-axis
#     - for metric in dice, jaccard, auc... # one plot per metric type
#         for im_f_type in (f1, f2, f2-f1, f1+f2, 2f1, 2f2, 2f1-f2, 2f2-f1)...
#             - f1_only, f2_only, f1, f2, f1&f2, and f1&f1_f2_dil_2mm
#
# For each metric have a raw metric matrix, and an associated p-value matrix

# %%
roi_types = [i for i in df.roi_map.unique()]
frequency_text_codes = get_frequency_text_codes()
roi_c_dict = get_roi_colour_codes()
from matplotlib.markers import MarkerStyle

def scale_value(x):
    proportion = (x - 0.5) / (1 - 0.5)
    scaled_value = proportion * (1 - 0.05) + 0.05
    return scaled_value

for metric_type in ["dice","jaccard","auc"]:

    for sub_ix, (experiment_id,sub_id,roi_task_id) in enumerate(zip(_experiment_ids,sub_ids, roi_task_ids)):
        columns = []
        row_metrics = []
        row_p_values = []
        for im_f_type, roi_type in itertools.product(im_strs, roi_types):
            _df = df[(df.experiment_id==experiment_id) & (df.sub_id==sub_id) & (df.roi_task_id==roi_task_id) & (df.metric_type==metric_type) & (df.im_map==im_f_type) & (df.roi_map==roi_type)]
            if _df.shape[0] == 0:
                f"Warning: No data loaded for [{experiment_id}, {sub_id}, {im_f_type}, {roi_type}] presumably due to no vertices in this case."
                columns.append((im_f_type, roi_type))  
                row_metrics.append(-1)
                row_p_values.append(-1)
            else:
                assert _df.shape[0] == 1, f"{_df.shape}"
                metric = _df.metric.values[0]
                p_value = _df.p_value.values[0]
                columns.append((im_f_type, roi_type))  
                row_metrics.append(metric)
                row_p_values.append(p_value)

        if sub_ix == 0:
            metrics = np.array(row_metrics)
            p_values = np.array(row_p_values)
        else:
            metrics = np.vstack((metrics, np.array(row_metrics)))
            p_values = np.vstack((p_values, np.array(row_p_values)))

    # Plot figure for each metric
    fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(6,4), dpi=300)
    empty_metrics = np.ma.array(np.zeros_like(metrics), mask=(np.zeros_like(metrics)==0))
    cmap = plt.get_cmap("binary")
    cmap.set_bad('white')
    im = ax.imshow(empty_metrics, cmap=cmap, interpolation='none', aspect='auto')
    pval_marker_s = 20
    for i in range(metrics.shape[0]):
        for j in range(metrics.shape[1]):
            _metric = metrics[i,j]
            _pval = p_values[i,j]
            # Plot ROIs that had no vertex allocated
            if _metric == -1 or np.isnan(_metric):
                ax.scatter(j+.5, i, s=10, marker='x',c='k',linewidths=.25)
                continue
            elif _metric < 0:
                print(f"WARNING: Skipping {j+.5}, {i}, a negative value detected: {_metric}.")
                continue
            # Marker color
            if _pval>1:
                raise ValueError()
            elif _pval < .05:
                c='red'
            else:
                c='lightgrey'
            # Marker size
            if metric_type == "auc":
                if _metric <= .5:
                    s = .05 * pval_marker_s
                else:
                    s = scale_value(_metric) * pval_marker_s
            else:
                s = _metric * pval_marker_s
            ax.scatter(j+.5,i,s=s,edgecolors=c,c=c,linewidths=.25)
    
    for i in ("top", "right", "bottom", "left"):
        ax.spines[i].set_visible(False)

    linewidth=.25
    ax.tick_params(axis="y", length=4, width=linewidth,pad=0)
    ax.set_yticks([i for i in range(len(sub_ids))])
    ax.set_yticklabels(sub_ids, fontsize=FONTSIZE)

    n_im_f_types = 8
    n_spatial_comparisons_per_im = metrics.shape[-1] / n_im_f_types

    xtick_pos = []
    xtick_labels = []
    for i in range(len(columns)):
        im_f_type, roi_type = columns[i]
        if roi_type == "IM":
            xtick_pos.append(i+n_spatial_comparisons_per_im/2)
            xtick_labels.append(frequency_text_codes[im_f_type])
    ax.set_xlim(min(xtick_pos)-.5, max(xtick_pos)+7.5)
    ax.set_xticks(xtick_pos)
    ax.set_xticklabels(xtick_labels, fontsize=FONTSIZE, rotation=0)
    ax.tick_params(axis="x", length=0, width=linewidth,pad=0, top=True, labeltop=True, labelbottom=False, bottom=False,rotation=0)

    x_boundary = 0
    for i in range(n_im_f_types):
        ax.plot([x_boundary,x_boundary],[ax.get_ylim()[0],ax.get_ylim()[-1]], c='k', linewidth=.25,linestyle='dotted')
        x_boundary += n_spatial_comparisons_per_im
        if i == n_im_f_types-1:
            ax.plot([x_boundary,x_boundary],[ax.get_ylim()[0],ax.get_ylim()[-1]], c='k', linewidth=.25,linestyle='dotted')

    ax.set_ylim(ax.get_ylim()[0], ax.get_ylim()[-1]-1)
    ax.set_xlim(0,n_im_f_types*n_spatial_comparisons_per_im)

    pval_marker_s = 10
    for i in range(n_im_f_types):
        x_start = i * n_spatial_comparisons_per_im + .5
        y_pos = ax.get_ylim()[-1]+.5
        ax.scatter(x_start,y_pos, marker=MarkerStyle('o',fillstyle='full'),c="k", edgecolors='k',s=pval_marker_s, linewidths=.25)
        ax.scatter(x_start+1,y_pos, marker=MarkerStyle('o',fillstyle='full'),c=roi_c_dict["f1"], edgecolors='k',s=pval_marker_s, linewidths=.25)
        ax.scatter(x_start+2,y_pos, marker=MarkerStyle('o',fillstyle='full'),c=roi_c_dict["f2"], edgecolors='k',s=pval_marker_s, linewidths=.25)
        ax.scatter(x_start+3,y_pos, marker=MarkerStyle('o',fillstyle='left'),c=roi_c_dict["f1"], edgecolors='k',s=pval_marker_s, linewidths=.25)
        ax.scatter(x_start+3,y_pos, marker=MarkerStyle('o',fillstyle='right'),c=roi_c_dict["f1f2"], edgecolors='k',s=pval_marker_s, linewidths=.25)
        ax.scatter(x_start+4,y_pos, marker=MarkerStyle('o',fillstyle='left'),c=roi_c_dict["f2"], edgecolors='k',s=pval_marker_s, linewidths=.25)
        ax.scatter(x_start+4,y_pos, marker=MarkerStyle('o',fillstyle='right'),c=roi_c_dict["f1f2"], edgecolors='k',s=pval_marker_s, linewidths=.25)
        ax.scatter(x_start+5,y_pos, marker=MarkerStyle('o',fillstyle='full'),c=roi_c_dict["f1f2"], edgecolors='k',s=pval_marker_s, linewidths=.25)
        ax.scatter(x_start+6,y_pos, marker=MarkerStyle('o',fillstyle='full'),c=roi_c_dict["f1f2"], edgecolors='k',s=pval_marker_s*2, linewidths=.25)
# Out:
# WARNING: Skipping 2.5, 0, a negative value detected: -0.05981923285746227.
# WARNING: Skipping 4.5, 0, a negative value detected: -0.022516048672990396.
# WARNING: Skipping 8.5, 0, a negative value detected: -0.14886385396055402.
# WARNING: Skipping 10.5, 0, a negative value detected: -0.09021350609561501.
# WARNING: Skipping 16.5, 0, a negative value detected: -0.00652964205816553.
# WARNING: Skipping 18.5, 0, a negative value detected: -0.0025167785234899154.
# WARNING: Skipping 20.5, 0, a negative value detected: -0.002288737083200265.
# WARNING: Skipping 22.5, 0, a negative value detected: -0.10666404372935717.
# WARNING: Skipping 23.5, 0, a negative value detected: -0.05021423296120908.
# WARNING: Skipping 24.5, 0, a negative value detected: -0.13674905542559734.
# WARNING: Skipping 25.5, 0, a negative value detected: -0.07996753421704922.
# WARNING: Skipping 26.5, 0, a negative value detected: -0.030013891266173487.
# WARNING: Skipping 27.5, 0, a negative value detected: -0.0690551640960298.
# WARNING: Skipping 30.5, 0, a negative value detected: -0.05977341630764321.
# WARNING: Skipping 32.5, 0, a negative value detected: -0.09814903462581775.
# WARNING: Skipping 33.5, 0, a negative value detected: -0.03835966172012123.
# WARNING: Skipping 34.5, 0, a negative value detected: -0.19534067336843786.
# WARNING: Skipping 36.5, 0, a negative value detected: -0.14886860498515941.
# WARNING: Skipping 38.5, 0, a negative value detected: -0.10962244279194461.
# WARNING: Skipping 41.5, 0, a negative value detected: -0.026234321641719627.
# WARNING: Skipping 44.5, 0, a negative value detected: -0.0007701900226084191.
# WARNING: Skipping 50.5, 0, a negative value detected: -0.10511445263863617.
# WARNING: Skipping 51.5, 0, a negative value detected: -0.059796315806276534.
# WARNING: Skipping 52.5, 0, a negative value detected: -0.03339292745479899.
# WARNING: Skipping 2.5, 1, a negative value detected: -0.045100222717149197.
# WARNING: Skipping 4.5, 1, a negative value detected: -0.015153448460102192.
# WARNING: Skipping 8.5, 1, a negative value detected: -0.22021844435531152.
# WARNING: Skipping 10.5, 1, a negative value detected: -0.08534139643948047.
# WARNING: Skipping 16.5, 1, a negative value detected: -0.02671038600501796.
# WARNING: Skipping 18.5, 1, a negative value detected: -0.03174917051727916.
# WARNING: Skipping 19.5, 1, a negative value detected: -0.0036470337238500017.
# WARNING: Skipping 20.5, 1, a negative value detected: -0.018043293392825732.
# WARNING: Skipping 23.5, 1, a negative value detected: -0.04498472740736165.
# WARNING: Skipping 25.5, 1, a negative value detected: -0.09337879115115238.
# WARNING: Skipping 26.5, 1, a negative value detected: -0.04836321002128907.
# WARNING: Skipping 27.5, 1, a negative value detected: -0.03703063774644416.
# WARNING: Skipping 29.5, 1, a negative value detected: -0.22019126947400897.
# WARNING: Skipping 30.5, 1, a negative value detected: -0.04497917630726511.
# WARNING: Skipping 31.5, 1, a negative value detected: -0.26857936140675615.
# WARNING: Skipping 32.5, 1, a negative value detected: -0.09336726824001235.
# WARNING: Skipping 33.5, 1, a negative value detected: -0.048357242017584456.
# WARNING: Skipping 36.5, 1, a negative value detected: -0.22020485607626566.
# WARNING: Skipping 37.5, 1, a negative value detected: -0.044981951686051846.
# WARNING: Skipping 38.5, 1, a negative value detected: -0.2685959337302934.
# WARNING: Skipping 39.5, 1, a negative value detected: -0.09337302934007957.
# WARNING: Skipping 40.5, 1, a negative value detected: -0.04836022583531302.
# WARNING: Skipping 44.5, 1, a negative value detected: -0.027437081239773453.
# WARNING: Skipping 46.5, 1, a negative value detected: -0.02206606267127814.
# WARNING: Skipping 50.5, 1, a negative value detected: -0.06715312702477555.
# WARNING: Skipping 52.5, 1, a negative value detected: -0.11324241769769522.
# WARNING: Skipping 54.5, 1, a negative value detected: -0.04836321002128907.
# WARNING: Skipping 55.5, 1, a negative value detected: -0.07604208447749222.
# WARNING: Skipping 2.5, 2, a negative value detected: -0.05426816500314091.
# WARNING: Skipping 4.5, 2, a negative value detected: -0.06255851623291447.
# WARNING: Skipping 5.5, 2, a negative value detected: -0.005274584038336139.
# WARNING: Skipping 15.5, 2, a negative value detected: -0.00302187540600235.
# WARNING: Skipping 17.5, 2, a negative value detected: -0.04222546121865667.
# WARNING: Skipping 18.5, 2, a negative value detected: -0.043857184617383416.
# WARNING: Skipping 19.5, 2, a negative value detected: -0.04555143237625048.
# WARNING: Skipping 20.5, 2, a negative value detected: -0.05915697674418602.
# WARNING: Skipping 22.5, 2, a negative value detected: -0.1048749136979284.
# WARNING: Skipping 23.5, 2, a negative value detected: -0.015624095220217404.
# WARNING: Skipping 24.5, 2, a negative value detected: -0.13398233551700117.
# WARNING: Skipping 25.5, 2, a negative value detected: -0.04696916669583173.
# WARNING: Skipping 26.5, 2, a negative value detected: -0.02947426527904612.
# WARNING: Skipping 27.5, 2, a negative value detected: -0.06215944486689595.
# WARNING: Skipping 30.5, 2, a negative value detected: -0.05423031317569921.
# WARNING: Skipping 32.5, 2, a negative value detected: -0.11097161191323152.
# WARNING: Skipping 33.5, 2, a negative value detected: -0.05667154913859246.
# WARNING: Skipping 34.5, 2, a negative value detected: -0.05101795664674924.
# WARNING: Skipping 36.5, 2, a negative value detected: -0.20260799832641818.
# WARNING: Skipping 37.5, 2, a negative value detected: -0.05421707750775773.
# WARNING: Skipping 38.5, 2, a negative value detected: -0.25933544855479235.
# WARNING: Skipping 39.5, 2, a negative value detected: -0.11094452773613189.
# WARNING: Skipping 40.5, 2, a negative value detected: -0.056657717652801476.
# WARNING: Skipping 41.5, 2, a negative value detected: -0.25473309856699555.
# WARNING: Skipping 44.5, 2, a negative value detected: -0.03877919256697604.
# WARNING: Skipping 50.5, 2, a negative value detected: -0.20260093438393423.
# WARNING: Skipping 51.5, 2, a negative value detected: -0.025277177323757116.
# WARNING: Skipping 2.5, 3, a negative value detected: -0.06164362844439064.
# WARNING: Skipping 8.5, 3, a negative value detected: -0.14673682937155996.
# WARNING: Skipping 22.5, 3, a negative value detected: -0.06534146019523063.
# WARNING: Skipping 23.5, 3, a negative value detected: -0.03487917207070007.
# WARNING: Skipping 24.5, 3, a negative value detected: -0.09970575603541548.
# WARNING: Skipping 25.5, 3, a negative value detected: -0.06938759610707207.
# WARNING: Skipping 26.5, 3, a negative value detected: -0.034435851005785056.
# WARNING: Skipping 27.5, 3, a negative value detected: -0.09556398167801411.
# WARNING: Skipping 29.5, 3, a negative value detected: -0.14671908073782886.
# WARNING: Skipping 30.5, 3, a negative value detected: -0.06162685213184155.
# WARNING: Skipping 31.5, 3, a negative value detected: -0.1890686422739643.
# WARNING: Skipping 32.5, 3, a negative value detected: -0.103976413667977.
# WARNING: Skipping 33.5, 3, a negative value detected: -0.042334442092530955.
# WARNING: Skipping 34.5, 3, a negative value detected: -0.20937405503477474.
# WARNING: Skipping 36.5, 3, a negative value detected: -0.14671908073782886.
# WARNING: Skipping 37.5, 3, a negative value detected: -0.06162685213184155.
# WARNING: Skipping 38.5, 3, a negative value detected: -0.1890686422739643.
# WARNING: Skipping 39.5, 3, a negative value detected: -0.103976413667977.
# WARNING: Skipping 40.5, 3, a negative value detected: -0.042334442092530955.
# WARNING: Skipping 41.5, 3, a negative value detected: -0.20937405503477474.
# WARNING: Skipping 44.5, 3, a negative value detected: -0.03920252435040156.
# WARNING: Skipping 46.5, 3, a negative value detected: -0.04402689994198655.
# WARNING: Skipping 47.5, 3, a negative value detected: -0.003747309242465968.
# WARNING: Skipping 48.5, 3, a negative value detected: -0.011522119553601384.
# WARNING: Skipping 50.5, 3, a negative value detected: -0.09624807186280737.
# WARNING: Skipping 52.5, 3, a negative value detected: -0.07597805704261562.
# WARNING: Skipping 2.5, 4, a negative value detected: -0.04915887850467293.
# WARNING: Skipping 4.5, 4, a negative value detected: -0.0836955439017959.
# WARNING: Skipping 5.5, 4, a negative value detected: -0.032955957996241736.
# WARNING: Skipping 6.5, 4, a negative value detected: -0.0741540444730906.
# WARNING: Skipping 8.5, 4, a negative value detected: -0.23733076741280934.
# WARNING: Skipping 10.5, 4, a negative value detected: -0.14233168649252925.
# WARNING: Skipping 16.5, 4, a negative value detected: -0.04318383543573312.
# WARNING: Skipping 18.5, 4, a negative value detected: -0.06742276828692112.
# WARNING: Skipping 19.5, 4, a negative value detected: -0.023893218054829468.
# WARNING: Skipping 20.5, 4, a negative value detected: -0.11251490916016788.
# WARNING: Skipping 22.5, 4, a negative value detected: -0.17311176377917303.
# WARNING: Skipping 24.5, 4, a negative value detected: -0.23753460266018495.
# WARNING: Skipping 25.5, 4, a negative value detected: -0.04603279094366797.
# WARNING: Skipping 26.5, 4, a negative value detected: -0.07016744311660256.
# WARNING: Skipping 28.5, 4, a negative value detected: -1.1102230246251565e-16.
# WARNING: Skipping 29.5, 4, a negative value detected: -0.23726668241806464.
# WARNING: Skipping 31.5, 4, a negative value detected: -0.30743916022547.
# WARNING: Skipping 33.5, 4, a negative value detected: -0.07015560130961623.
# WARNING: Skipping 34.5, 4, a negative value detected: -0.2883855942214872.
# WARNING: Skipping 44.5, 4, a negative value detected: -0.041080165494227994.
# WARNING: Skipping 46.5, 4, a negative value detected: -0.06528115981240984.
# WARNING: Skipping 47.5, 4, a negative value detected: -0.0211653363997113.
# WARNING: Skipping 48.5, 4, a negative value detected: -0.020545860389610426.
# WARNING: Skipping 50.5, 4, a negative value detected: -0.007610430823691727.
# WARNING: Skipping 51.5, 4, a negative value detected: -0.048833597785354954.
# WARNING: Skipping 2.5, 5, a negative value detected: -0.05517937143052565.
# WARNING: Skipping 4.5, 5, a negative value detected: -0.02664480317551282.
# WARNING: Skipping 17.5, 5, a negative value detected: -0.01373058052296866.
# WARNING: Skipping 18.5, 5, a negative value detected: -0.01232576555394993.
# WARNING: Skipping 19.5, 5, a negative value detected: -0.01692978374274451.
# WARNING: Skipping 20.5, 5, a negative value detected: -0.030432432873715276.
# WARNING: Skipping 22.5, 5, a negative value detected: -0.2091704250375837.
# WARNING: Skipping 23.5, 5, a negative value detected: -0.05512846795134618.
# WARNING: Skipping 24.5, 5, a negative value detected: -0.2686893535602023.
# WARNING: Skipping 25.5, 5, a negative value detected: -0.11464739647396471.
# WARNING: Skipping 26.5, 5, a negative value detected: -0.05950184501845013.
# WARNING: Skipping 27.5, 5, a negative value detected: -0.07847307639743062.
# WARNING: Skipping 33.5, 5, a negative value detected: -0.05950184501845013.
# WARNING: Skipping 36.5, 5, a negative value detected: -0.04977042807819537.
# WARNING: Skipping 38.5, 5, a negative value detected: -0.049046099490555606.
# WARNING: Skipping 44.5, 5, a negative value detected: -0.008146594282863961.
# WARNING: Skipping 46.5, 5, a negative value detected: -0.007664230147694406.
# WARNING: Skipping 48.5, 5, a negative value detected: -0.028802768942383317.
# WARNING: Skipping 2.5, 6, a negative value detected: -0.06605189791979416.
# WARNING: Skipping 7.5, 6, a negative value detected: -2.220446049250313e-16.
# WARNING: Skipping 8.5, 6, a negative value detected: -0.15410175789624125.
# WARNING: Skipping 10.5, 6, a negative value detected: -0.20185436615692443.
# WARNING: Skipping 11.5, 6, a negative value detected: -2.220446049250313e-16.
# WARNING: Skipping 12.5, 6, a negative value detected: -0.04773474346148354.
# WARNING: Skipping 13.5, 6, a negative value detected: -0.2270615978276404.
# WARNING: Skipping 16.5, 6, a negative value detected: -0.015530899205244642.
# WARNING: Skipping 22.5, 6, a negative value detected: -0.11069606224171447.
# WARNING: Skipping 23.5, 6, a negative value detected: -0.025916202032984836.
# WARNING: Skipping 24.5, 6, a negative value detected: -0.1507466903199166.
# WARNING: Skipping 25.5, 6, a negative value detected: -0.0646241051486039.
# WARNING: Skipping 26.5, 6, a negative value detected: -0.03884921206436692.
# WARNING: Skipping 27.5, 6, a negative value detected: -0.08034832417693594.
# WARNING: Skipping 29.5, 6, a negative value detected: -0.15410726408689746.
# WARNING: Skipping 31.5, 6, a negative value detected: -0.20186157859005965.
# WARNING: Skipping 33.5, 6, a negative value detected: -0.04773644906563762.
# WARNING: Skipping 34.5, 6, a negative value detected: -0.0219834208739772.
# WARNING: Skipping 37.5, 6, a negative value detected: -0.0660330165082541.
# WARNING: Skipping 44.5, 6, a negative value detected: -0.04892274378564471.
# WARNING: Skipping 46.5, 6, a negative value detected: -0.060529604818171545.
# WARNING: Skipping 47.5, 6, a negative value detected: -0.009817274721655278.
# WARNING: Skipping 48.5, 6, a negative value detected: -0.04879763816268007.
# WARNING: Skipping 53.5, 6, a negative value detected: -0.003626943005181349.
# WARNING: Skipping 54.5, 6, a negative value detected: -0.04773986063962837.
# WARNING: Skipping 55.5, 6, a negative value detected: -0.021984991959978495.
# WARNING: Skipping 2.5, 7, a negative value detected: -0.0729010056463199.
# WARNING: Skipping 4.5, 7, a negative value detected: -0.046578658692771224.
# WARNING: Skipping 6.5, 7, a negative value detected: -0.0916162729834174.
# WARNING: Skipping 8.5, 7, a negative value detected: -0.16557021205543498.
# WARNING: Skipping 9.5, 7, a negative value detected: -0.017961262314242554.
# WARNING: Skipping 16.5, 7, a negative value detected: -0.04650284966096996.
# WARNING: Skipping 18.5, 7, a negative value detected: -0.05414650737137211.
# WARNING: Skipping 19.5, 7, a negative value detected: -0.006609562042791173.
# WARNING: Skipping 22.5, 7, a negative value detected: -0.1655868011488879.
# WARNING: Skipping 24.5, 7, a negative value detected: -0.21857257364237526.
# WARNING: Skipping 26.5, 7, a negative value detected: -0.05293567563956986.
# WARNING: Skipping 27.5, 7, a negative value detected: -0.08839268740076967.
# WARNING: Skipping 29.5, 7, a negative value detected: -0.0479616707288571.
# WARNING: Skipping 30.5, 7, a negative value detected: -0.07285232546492604.
# WARNING: Skipping 31.5, 7, a negative value detected: -0.0939910186638176.
# WARNING: Skipping 32.5, 7, a negative value detected: -0.1258221762211612.
# WARNING: Skipping 33.5, 7, a negative value detected: -0.0529197689559614.
# WARNING: Skipping 34.5, 7, a negative value detected: -0.14178575005842875.
# WARNING: Skipping 36.5, 7, a negative value detected: -0.16554257095158592.
# WARNING: Skipping 38.5, 7, a negative value detected: -0.14507178631051754.
# WARNING: Skipping 41.5, 7, a negative value detected: -0.04333555926544247.
# WARNING: Skipping 50.5, 7, a negative value detected: -0.023596874895662923.
# WARNING: Skipping 2.5, 8, a negative value detected: -0.06101195756306993.
# WARNING: Skipping 8.5, 8, a negative value detected: -0.18685489305856068.
# WARNING: Skipping 9.5, 8, a negative value detected: -0.3416096194090731.
# WARNING: Skipping 16.5, 8, a negative value detected: -0.021482981809184676.
# WARNING: Skipping 23.5, 8, a negative value detected: -0.06099897122991238.
# WARNING: Skipping 25.5, 8, a negative value detected: -0.05702072236890782.
# WARNING: Skipping 32.5, 8, a negative value detected: -0.010243720732226513.
# WARNING: Skipping 33.5, 8, a negative value detected: -0.05837590464027248.
# WARNING: Skipping 37.5, 8, a negative value detected: -0.06098815350783854.
# WARNING: Skipping 39.5, 8, a negative value detected: -0.11936936936936937.
# WARNING: Skipping 40.5, 8, a negative value detected: -0.05836348159182808.
# WARNING: Skipping 44.5, 8, a negative value detected: -0.0013126874233927444.
# WARNING: Skipping 50.5, 8, a negative value detected: -0.1272597216803225.
# WARNING: Skipping 51.5, 8, a negative value detected: -0.06099031674529143.
# WARNING: Skipping 21.5, 16, a negative value detected: -1.1102230246251565e-16.
# WARNING: Skipping 35.5, 19, a negative value detected: -2.220446049250313e-16.
# WARNING: Skipping 49.5, 19, a negative value detected: -2.220446049250313e-16.
# WARNING: Skipping 21.5, 28, a negative value detected: -2.220446049250313e-16.
# WARNING: Skipping 28.5, 28, a negative value detected: -1.1102230246251565e-16.
# WARNING: Skipping 28.5, 33, a negative value detected: -1.1102230246251565e-16.

# %% [markdown]
# # $f_2$-$f_1$

# %% [markdown]
# AUC:
# - `fpr, tpr, _ = roc_curve(im_labels, predicted_labels)`
#     - `im_labels==BINARIZE(f_IM[fo>=.8])` ground truth,
#     - `predicted_labels=BINARIZED(f_IM[fo>=FO])` where FO is variable. FO is varied over various brain maps depending on the comparisons
#         - f1-only
#         - f2-only
#         - multiplex, etc.etc
# - Calculate list of fpr and tpr over `fo_range = np.arange(0,1+.05,.05)`
# - Calculate area under curve with list of fpr and tpr

# %%
from scipy.stats import wilcoxon
text_dict = get_frequency_text_codes()

# %%
metric_type = "dice"
im_code = "f2-f1"
FONTSIZE = 8
df.roi_map.unique()
# Out:
# array(['IM', 'f1_only', 'f2_only', 'f1', 'f2', 'f1&f2', 'f1&f2_dil2mm'],
#       dtype=object)

# %% [markdown]
# Show overlap between $f_2$-$f_1$ and fundamental frequencies across all experiments

# %%
#import itertools
#for im_code,metric_type in itertools.product(df.im_map.unique(),df.metric_type.unique()):

fig, ax = plt.subplots(figsize=(2,2), dpi=300,tight_layout=True)
roi_maps = ["f1_only","f2_only","f1&f2"]
xlabels = []
xticks = []
all_metrics = {}
for xpos, roi_map in enumerate(roi_maps):
    if roi_map == "IM":
        continue
    xlabels.append(roi_map)
    xticks.append(xpos)
    _metric = df[(df.metric_type==metric_type) & (df.im_map==im_code) & (df.roi_map==roi_map) & (~df.experiment_id.str.contains("Control"))].metric
    all_metrics[roi_map] = _metric
    _pvalue = df[(df.metric_type==metric_type) & (df.im_map==im_code) & (df.roi_map==roi_map) & (~df.experiment_id.str.contains("Control"))].p_value
    _pvalue = ["r" if i < .05 else "k" for i in _pvalue]
    _xpos = np.zeros_like(_metric) + xpos
    _xjitter = np.zeros_like(_metric) + np.random.uniform(-.25,.25,_metric.shape[0])
    _xpos += _xjitter

    for x,y,p in zip(_xpos,_metric,_pvalue):
        marker='o'
        s=20
        if p=='k':
            marker="x"
            s=10
            ax.scatter(x,y,marker=marker,c=p,linewidths=.25,s=s)
        else:
            s=12
            ax.scatter(x,y,marker=marker,c="k",linewidths=.25,s=s,edgecolors='k')

    total_p = sum([i=="r" for i in _pvalue])
    total_r = len(_pvalue)
    ax.text(xpos+.7,_metric.max()-.1,f"n={total_p}/{total_r}",fontsize=FONTSIZE-2, ha="center",va="center")
    #ax.scatter(_xpos, _metric, marker='o',c=_pvalue, edgecolors='k',s=10, linewidths=.25)

ax.set_xticks(xticks)
ax.set_xticklabels(xlabels,fontsize=FONTSIZE, rotation=90)
ax.set_xlabel("Regions",fontsize=FONTSIZE)
ax.set_ylabel(metric_type.upper(), fontsize=FONTSIZE)
ax.set_title(text_dict[im_code], fontsize=FONTSIZE,y=1.1)

ax.set_xticks([0,1,2])
ax.set_xticklabels([text_dict["f1"],text_dict["f2"],"Multiplex"],fontsize=FONTSIZE,rotation=0)

ax.tick_params(axis="both", length=4, width=linewidth,pad=1)

for _spine in ("right","top","bottom"):
    ax.spines[_spine].set_visible(False)
ax.spines.left.set_linewidth(linewidth)

for roi1,roi2 in itertools.combinations(all_metrics.keys(),2):
    pval = wilcoxon(all_metrics[roi1],all_metrics[roi2]).pvalue*3
    if pval <.05:
        pval_txt = "*"
        if pval < .01:
            pval_txt = "**"
        if pval < .001:
            pval_txt = "***"
        _max = pd.concat((all_metrics[roi1],all_metrics[roi2])).max() + .075
        if roi1 == "f1_only" and roi2 == "f2_only":
            ax.plot([0,1],[_max,_max], c='k', linewidth=linewidth,linestyle='-')
            ax.text(.5,_max+.01,pval_txt,fontsize=FONTSIZE, ha="center",va="center")
        if roi1 == "f1_only" and roi2 == "f1&f2":
            _max -=.04
            ax.plot([0,2],[_max,_max], c='k', linewidth=linewidth,linestyle='-')
            ax.text(1,_max+.01,pval_txt,fontsize=FONTSIZE, ha="center",va="center")
        if roi1 == "f2_only" and roi2 == "f1&f2":
            _max +=.04
            ax.plot([1,2],[_max,_max], c='k', linewidth=linewidth,linestyle='-')
            ax.text(1.5,_max+.01,pval_txt,fontsize=FONTSIZE, ha="center",va="center")
        print(roi1,roi2,pval)

if metric_type == "auc":
    ax.set_yticks([.25,.5,.75,1])
    ax.set_yticklabels([.25,.5,.75,1],fontsize=FONTSIZE)
    ax.spines.left.set_bounds(.25,1)
else:
    if im_code == "2f1":
        ax.set_yticks([0,.2,.4])
        ax.set_yticklabels([0,.2,.4],fontsize=FONTSIZE)
        ax.spines.left.set_bounds(-.05,.4)
    else:
        ax.set_yticks([0,.25,.5,.75,1.])
        ax.set_yticklabels([0,.25,.5,.75,1.],fontsize=FONTSIZE)
        ax.spines.left.set_bounds(0,1.)


fig.savefig(MAIN / f"Figure_X_{im_code}_{metric_type}_spatial_surrogate_across_rois.png",dpi=300)

fig, ax = plt.subplots(figsize=(1,2),dpi=300)
ax.set_xlim(0,10)
ax.set_ylim(0,10)
offset=.05
FONTSIZE = 6
ax.scatter(1,1,marker='x',c="k",linewidths=.25,s=10)
ax.text(2,1-offset,"n.s.",fontsize=FONTSIZE,va="center",ha="left")
ax.scatter(1,2,marker='o',c="k",linewidths=.25,s=12,edgecolors='k')
ax.text(2,2-offset,"$p_{surr}$<.05",fontsize=FONTSIZE,va="center",ha="left")
for _spine in ("left","right","bottom","top"):
    ax.spines[_spine].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

fig.savefig(MAIN / f"Figure_X_spatial_surrogate_across_rois_schematic.png",dpi=300)
# Out:
# f1_only f2_only 9.584426879882812e-05
# f1_only f1&f2 0.0018939971923828125
# f2_only f1&f2 5.364418029785156e-07

# %% [markdown]
# A lot of significance, but the metric (dice score) varies

# %% [markdown]
# Does multiplexed populations better explain $f_2$-$f_1$ areas?
#
# - Compare multiplex to $f_1$ and $f_2$:
#     1. multiplex > all $f_1$,
#     2. multiplex > all $f_2$
#     3. multiplex > $f_1$ only
#     4. multiplex > $f_2$ only
#
# - Compare multiplex dilation:
#     1. multiplex + 2mm dilation > multiplex

# %%
from scipy.stats import wilcoxon
import itertools

# %%
all_roi_maps = [
    ["f1","f1&f2"], #1
    ["f2","f1&f2"], #2
    ["f1_only","f1&f2"], #3
    ["f2_only","f1&f2"], #4
    ["f1&f2","f1&f2_dil2mm"], #5
]


for roi_maps in all_roi_maps:
    fig, ax = plt.subplots(figsize=(2,1), dpi=300)
    xlabels = []
    xticks = []
    # Scatter
    for xpos, roi_map in enumerate(roi_maps):
        if roi_map == "IM":
            continue
        xlabels.append(roi_map)
        xticks.append(xpos)
        _metric = df[(df.metric_type==metric_type) & (df.im_map==im_code) & (df.roi_map==roi_map) & (~df.experiment_id.str.contains("Control"))].metric
        _xpos = np.zeros_like(_metric) + xpos

        ax.scatter(_xpos, _metric, marker='o',c='white', edgecolors='k',s=10, linewidths=.25,zorder=1)
        ax.scatter(_xpos[0], _metric.mean(), marker='o',c='k', edgecolors='k',s=10, linewidths=.25,zorder=2)
    # Plot
    for (xpos_1, roi_map_1), (xpos_2, roi_map_2) in itertools.combinations(enumerate(roi_maps), 2):
        metric1 = df[(df.metric_type==metric_type) & (df.im_map==im_code) & (df.roi_map==roi_map_1) & (~df.experiment_id.str.contains("Control"))].metric
        metric2 = df[(df.metric_type==metric_type) & (df.im_map==im_code) & (df.roi_map==roi_map_2) & (~df.experiment_id.str.contains("Control"))].metric

        if xpos_1 < xpos_2:
            xpos_1 += .1
            xpos_2 -= .1
        else:
            xpos_1 -= .1
            xpos_2 += .1

        count = 0
        for _metric1, _metric2 in zip(metric1, metric2):
            c='grey'
            if _metric2 > _metric1:
                count+=1
                c='r'
            ax.plot([xpos_1, xpos_2], [_metric1, _metric2], color=c,linewidth=.5, linestyle='-')


    _wilc = wilcoxon(metric1, metric2)

    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels,fontsize=FONTSIZE, rotation=90)
    ax.set_xlabel("Regions",fontsize=FONTSIZE)
    ax.set_ylabel(metric_type, fontsize=FONTSIZE)
    ax.set_title(f"IM={im_code}\n{roi_map_2}>{roi_map_1} [n={count}/25]\n$p$={_wilc.pvalue:.3f}", fontsize=FONTSIZE,)

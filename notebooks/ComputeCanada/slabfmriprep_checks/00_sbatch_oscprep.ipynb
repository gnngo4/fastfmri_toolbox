# %%
def search(base_dir, wildcard, error=True):
    search_path = Path(base_dir) / wildcard
    files = glob.glob(str(search_path))
    
    if not files:
        if error:
            raise FileNotFoundError(f"No files were found in: {search_path}")
        else:
            return []

    return files

# %%
from pathlib import Path
import itertools
import glob
import os
import nibabel as nib

from collections import defaultdict, Counter

experiment_ids = ['1_attention']
mri_ids = ['7T']
VASO_FLAG = False
time_str="16:00:00" # Vaso: 18:00:00 48GB # WB: 08:00:00 32GB # SLAB: 16:00:00 48GB
SET_GB = "48GB"
ACCOUNT = "def-mmur"

oscprep_dir = 'oscprep_grayords_fmapless'

for experiment_id, mri_id in zip(experiment_ids, mri_ids):
    base_bids_dir = f'/data/{experiment_id}/{mri_id}/bids'
    sub_ids = [Path(i).stem for i in search(base_bids_dir, 'sub-*')]
    sub_ids.sort()
    print(mri_id, sub_ids)

    oscprep_deriv_dir = f"{base_bids_dir}/derivatives/oscprep_grayords_fmapless"
    assert Path(oscprep_deriv_dir).exists()
    
    for sub_id in sub_ids:
        #if sub_id not in ["sub-021", "sub-020"]:
            #continue
        sub_dir = f'{base_bids_dir}/{sub_id}'
        ses_ids = [Path(i).stem for i in search(sub_dir, 'ses-*')]
        ses_ids.sort()
        
        for ses_id in ses_ids:
            #if "Whole" not in ses_id:
                #continue
            ses_func_dir = f'{sub_dir}/{ses_id}/func'
            funcs = [Path(i).stem for i in search(ses_func_dir, '*part-mag*bold.nii.gz')]
            funcs.sort()

            vols_per_task_list = defaultdict(list)
            for func in funcs:
                nifti = Path(f"{ses_func_dir}/{func}.gz")
                task_id = func.split('task-')[1].split('_')[0]
                if task_id == 'wholebrain': continue
                n_vols = nib.load(nifti).shape[-1]
                vols_per_task_list[task_id].append(n_vols)

            vols_per_task = defaultdict(int)
            for k, v in vols_per_task_list.items():
                counter = Counter(v)
                vols_per_task[k] = counter.most_common(1)[0][0]

            for func in funcs:
                nifti = Path(f"{ses_func_dir}/{func}.gz")
                task_id = func.split('task-')[1].split('_')[0]
                if task_id == 'wholebrain': continue
                run_id = func.split('run-')[1].split('_')[0]
                n_vols = nib.load(nifti).shape[-1]
                inconsistent_vols = n_vols != vols_per_task[task_id]

                # Check if oscprep ran correctly
                oscprep_check_wildcards = [
                    f"{sub_id}_{ses_id}_task-{task_id}*run-{run_id}*space-T1w_boldref.nii.gz",
                    f"{sub_id}_{ses_id}_task-{task_id}*run-{run_id}*space-T1w_desc-boldref_brainmask.nii.gz",
                    f"{sub_id}_{ses_id}_task-{task_id}*run-{run_id}*space-T1w_desc-preproc_bold.nii.gz",
                    f"{sub_id}_{ses_id}_task-{task_id}*run-{run_id}*desc-preproc_bold.dtseries.nii",
                    f"{sub_id}_{ses_id}_task-{task_id}*run-{run_id}*desc-preproc_bold.json",
                    f"{sub_id}_{ses_id}_task-{task_id}*run-{run_id}*desc-confounds_timeseries.tsv",
                    f"{sub_id}_{ses_id}_task-{task_id}*run-{run_id}*desc-confounds_timeseries.json",
                ]

                preproc_flag = True
                preproc_paths = []
                for wildcard in oscprep_check_wildcards:
                    _path = search(f"{oscprep_deriv_dir}/bold_preproc/{sub_id}/{ses_id}/func", wildcard, error=False)
                    assert len(_path) in [0,1]
                    if len(_path) == 0:
                        preproc_flag = False
                    else:
                        preproc_paths += _path

                if not preproc_flag or inconsistent_vols:
                    print(
                        '\n',
                        experiment_id, 
                        mri_id, 
                        sub_id,
                        ses_id, 
                        task_id, 
                        run_id, 
                        f'\n[n_vols = {n_vols}, Expected: {vols_per_task[task_id]}]' if inconsistent_vols else '',
                        f'\n[oscprep incomplete]' if not preproc_flag else '',
                    )
                if not preproc_flag:
                    for _p in preproc_paths:
                        print(f"Removing {_p}")
                        os.remove(_p)
                    if VASO_FLAG:
                        sbatch_cmd = f"sbatch -J {experiment_id}.{mri_id}.{sub_id}_{ses_id}_task-{task_id}_{run_id}_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/{experiment_id}.{mri_id}.{sub_id}_{ses_id}_task-{task_id}_run-{run_id}_grayords_slurm-%j.out --time={time_str} --cpus-per-task=1 --mem-per-cpu={SET_GB} --account={ACCOUNT} ./run_minimal_preproc.grayords.vaso.sh {sub_id.split('-')[1]} {ses_id.split('-')[1]} {task_id} {run_id} /project/def-mmur/gngo4/data/fastfmri/{experiment_id}/{mri_id}/bids {oscprep_dir}"
                    else:
                        sbatch_cmd = f"sbatch -J {experiment_id}.{mri_id}.{sub_id}_{ses_id}_task-{task_id}_{run_id}_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/{experiment_id}.{mri_id}.{sub_id}_{ses_id}_task-{task_id}_run-{run_id}_grayords_slurm-%j.out --time={time_str} --cpus-per-task=1 --mem-per-cpu={SET_GB} --account={ACCOUNT} ./run_minimal_preproc.grayords.sh {sub_id.split('-')[1]} {ses_id.split('-')[1]} {task_id} {run_id} /project/def-mmur/gngo4/data/fastfmri/{experiment_id}/{mri_id}/bids {oscprep_dir}"
                    print(sbatch_cmd)
                    # !echo {sbatch_cmd} >> /data/scripts/02_minimal_preproc/tmp.sh
# Out:
# 7T ['sub-010', 'sub-011', 'sub-012', 'sub-013', 'sub-014', 'sub-015', 'sub-016', 'sub-Pilot001', 'sub-Pilot009', 'sub-Pilot010', 'sub-Pilot011']
#
#  1_attention 7T sub-010 ses-01 AttendInF2Q1 01
# [n_vols = 800, Expected: 880]
#
#  1_attention 7T sub-010 ses-02 AttendInF2Q1 01
# [n_vols = 800, Expected: 880]
#
#  1_attention 7T sub-012 ses-04 AttendInF1F2Q1 04
# [n_vols = 863, Expected: 880]
#
#  1_attention 7T sub-016 ses-02 AttendAwayQ2 01
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendAwayQ2_01_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendAwayQ2_run-01_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendAwayQ2 01 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendAwayQ2 02
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendAwayQ2_02_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendAwayQ2_run-02_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendAwayQ2 02 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendAwayQ2 03
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendAwayQ2_03_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendAwayQ2_run-03_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendAwayQ2 03 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendAwayQ2 04
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendAwayQ2_04_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendAwayQ2_run-04_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendAwayQ2 04 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF1F2Q2 01
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF1F2Q2_01_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF1F2Q2_run-01_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF1F2Q2 01 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF1F2Q2 02
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF1F2Q2_02_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF1F2Q2_run-02_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF1F2Q2 02 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF1F2Q2 03
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF1F2Q2_03_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF1F2Q2_run-03_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF1F2Q2 03 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF1F2Q2 04
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF1F2Q2_04_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF1F2Q2_run-04_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF1F2Q2 04 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF1Q2 01
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF1Q2_01_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF1Q2_run-01_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF1Q2 01 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF1Q2 02
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF1Q2_02_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF1Q2_run-02_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF1Q2 02 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF1Q2 03
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF1Q2_03_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF1Q2_run-03_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF1Q2 03 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF1Q2 04
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF1Q2_04_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF1Q2_run-04_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF1Q2 04 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF2Q2 01
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF2Q2_01_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF2Q2_run-01_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF2Q2 01 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF2Q2 02
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF2Q2_02_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF2Q2_run-02_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF2Q2 02 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF2Q2 03
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF2Q2_03_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF2Q2_run-03_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF2Q2 03 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-016 ses-02 AttendInF2Q2 04
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-016_ses-02_task-AttendInF2Q2_04_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-016_ses-02_task-AttendInF2Q2_run-04_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh 016 02 AttendInF2Q2 04 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendAwayQ1 01
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_01_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_run-01_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendAwayQ1 01 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendAwayQ1 02
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_02_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_run-02_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendAwayQ1 02 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendAwayQ1 03
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_03_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_run-03_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendAwayQ1 03 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendAwayQ1 04
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_04_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_run-04_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendAwayQ1 04 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendAwayQ1 05
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_05_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_run-05_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendAwayQ1 05 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendAwayQ1 06
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_06_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendAwayQ1_run-06_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendAwayQ1 06 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF1Q1 01
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_01_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_run-01_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF1Q1 01 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF1Q1 02
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_02_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_run-02_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF1Q1 02 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF1Q1 03
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_03_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_run-03_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF1Q1 03 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF1Q1 04
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_04_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_run-04_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF1Q1 04 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF1Q1 05
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_05_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_run-05_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF1Q1 05 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF1Q1 06
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_06_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF1Q1_run-06_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF1Q1 06 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF2Q1 01
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_01_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_run-01_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF2Q1 01 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF2Q1 02
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_02_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_run-02_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF2Q1 02 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF2Q1 03
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_03_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_run-03_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF2Q1 03 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF2Q1 04
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_04_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_run-04_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF2Q1 04 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF2Q1 05
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_05_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_run-05_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF2Q1 05 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-01 AttendInF2Q1 06
# [oscprep incomplete]
# sbatch -J 1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_06_grayords -D /project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc --output=/project/def-mmur/gngo4/data/fastfmri/scripts/02_minimal_preproc/logs/step_2/1_attention.7T.sub-Pilot001_ses-01_task-AttendInF2Q1_run-06_grayords_slurm-%j.out --time=16:00:00 --cpus-per-task=1 --mem-per-cpu=48GB --account=def-mmur ./run_minimal_preproc.grayords.sh Pilot001 01 AttendInF2Q1 06 /project/def-mmur/gngo4/data/fastfmri/1_attention/7T/bids oscprep_grayords_fmapless
#
#  1_attention 7T sub-Pilot001 ses-02 AttendAwayQ1 01
# [n_vols = 98, Expected: 800]
#
#  1_attention 7T sub-Pilot001 ses-03 localizerQ1 02
# [n_vols = 25, Expected: 75]
#
#  1_attention 7T sub-Pilot010 ses-03 AttendInF1Q1 04
# [n_vols = 322, Expected: 800]
